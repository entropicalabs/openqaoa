# %%
from openqaoa.qaoa_parameters.operators import PauliOp, Hamiltonian
from openqaoa.utilities import *

# %%
import networkx as nx
from networkx import fast_gnp_random_graph as gnp
from openqaoa.utilities import random_k_regular_graph

# %% [markdown]
# ## Constructing the Cost Hamiltonian and its squared (to compute uncertainty in expectation value)

# %%
# gr = gnp(10,0.5)
gr = random_k_regular_graph(4,[0,1,2,3,4,5,6,7],weighted=True,biases=True)

# %%
terms_list=list(nx.get_edge_attributes(gr,'weight').keys())
coeffs_list=list(nx.get_edge_attributes(gr,'weight').values())

# %%
cost_hamil = Hamiltonian.classical_hamiltonian(terms_list,coeffs_list,constant=0)

# %%
cost_hamil.expression
# Out:
# 0 + 0.06702560146732084Z_{1}Z_{5} + 0.13016355020174442Z_{0}Z_{3} + 0.13625548243139662Z_{0}Z_{7} + 0.1740274814854157Z_{5}Z_{7} + 0.31665766265129225Z_{3}Z_{4} + 0.47225554889952703Z_{1}Z_{4} + 0.47400483857728937Z_{2}Z_{4} + 0.47837669827699336Z_{3}Z_{5} + 0.5696538978618981Z_{2}Z_{7} + 0.7183935747774678Z_{6}Z_{7} + 0.7333619939498551Z_{3}Z_{6} + 0.7865505892699024Z_{1}Z_{6} + 0.7995067262310898Z_{0}Z_{4} + 0.8521424735441124Z_{1}Z_{2} + 0.924569917077484Z_{0}Z_{5} + 0.9561126724463139Z_{2}Z_{6}

# %%
len(cost_hamil)
# Out:
# 16

# %%
cost_hamil_squared = cost_hamil.hamiltonian_squared

# %%
cost_hamil_squared.expression
# Out:
# 2*0.00872429024139373Z_{0}Z_{1}Z_{3}Z_{5} + 2*0.009132605663184327Z_{0}Z_{1}Z_{5}Z_{7} + 2*0.011664296618403028Z_{1}Z_{7} + 2*0.017735497327721998Z_{3}Z_{7} + 2*0.02122417029843884Z_{1}Z_{3}Z_{4}Z_{5} + 2*0.02265203482281005Z_{0}Z_{3}Z_{5}Z_{7} + 2*0.02371219844611626Z_{0}Z_{5} + 2*0.03165321221127055Z_{4}Z_{5} + 2*0.031770459404063145Z_{1}Z_{2}Z_{4}Z_{5} + 2*0.032063485929966544Z_{1}Z_{3} + 2*0.038181395132397475Z_{1}Z_{2}Z_{5}Z_{7} + 2*0.041217285569278526Z_{0}Z_{4} + 2*0.04314634259015027Z_{0}Z_{3}Z_{4}Z_{7} + 2*0.048150761439718505Z_{1}Z_{5}Z_{6}Z_{7} + 2*0.04915402873776275Z_{1}Z_{3}Z_{5}Z_{6} + 2*0.05271902633029084Z_{5}Z_{6} + 2*0.05358741920280741Z_{0}Z_{1}Z_{4}Z_{5} + 2*0.05510713552426277Z_{3}Z_{4}Z_{5}Z_{7} + 2*0.05711536182514467Z_{2}Z_{5} + 2*0.061470458847235954Z_{0}Z_{1}Z_{3}Z_{4} + 2*0.06169815260202476Z_{0}Z_{2}Z_{3}Z_{4} + 2*0.06196985479070932Z_{0}Z_{1} + 2*0.062267209381522165Z_{0}Z_{5} + 2*0.06408402694124171Z_{1}Z_{2}Z_{5}Z_{6} + 2*0.06434740764620908Z_{0}Z_{1}Z_{4}Z_{7} + 2*0.06458575795516484Z_{0}Z_{2}Z_{4}Z_{7} + 2*0.06518144780767039Z_{0}Z_{3}Z_{5}Z_{7} + 2*0.07414817373196657Z_{0}Z_{2}Z_{3}Z_{7} + 2*0.07761846667209847Z_{0}Z_{2} + 2*0.08218544379249726Z_{1}Z_{4}Z_{5}Z_{7} + 2*0.08248986826950667Z_{2}Z_{4}Z_{5}Z_{7} + 2*0.08325069200245375Z_{3}Z_{7} + 2*0.09350865813515756Z_{0}Z_{3}Z_{6}Z_{7} + 2*0.09545700071554335Z_{0}Z_{6} + 2*0.09788506310691948Z_{0}Z_{6} + 2*0.09913543316325636Z_{2}Z_{5} + 2*0.09992459228248848Z_{0}Z_{3}Z_{6}Z_{7} + 0.0Z_{0}Z_{3} + 0.0Z_{0}Z_{4} + 0.0Z_{0}Z_{5} + 0.0Z_{0}Z_{7} + 0.0Z_{1}Z_{2} + 0.0Z_{1}Z_{4} + 0.0Z_{1}Z_{5} + 0.0Z_{1}Z_{6} + 0.0Z_{2}Z_{4} + 0.0Z_{2}Z_{6} + 0.0Z_{2}Z_{7} + 0.0Z_{3}Z_{4} + 0.0Z_{3}Z_{5} + 0.0Z_{3}Z_{6} + 0.0Z_{5}Z_{7} + 0.0Z_{6}Z_{7} + 2*0.1023802171126446Z_{0}Z_{1}Z_{3}Z_{6} + 2*0.10406663389641278Z_{3}Z_{4} + 2*0.10717182999766985Z_{0}Z_{1}Z_{6}Z_{7} + 2*0.10893717468976367Z_{4}Z_{7} + 2*0.11091788963419774Z_{0}Z_{1}Z_{2}Z_{3} + 2*0.11610908383303667Z_{0}Z_{1}Z_{2}Z_{7} + 2*0.12034530281653777Z_{3}Z_{5} + 2*0.1244510198384898Z_{0}Z_{2}Z_{3}Z_{6} + 2*0.12502022453382736Z_{5}Z_{6} + 2*0.12597772009294897Z_{5}Z_{7} + 2*0.12762514082421594Z_{3}Z_{5}Z_{6}Z_{7} + 2*0.1302755934429444Z_{0}Z_{2}Z_{6}Z_{7} + 2*0.13688141811151075Z_{1}Z_{5}Z_{6}Z_{7} + 2*0.13913614199664628Z_{0}Z_{4}Z_{5}Z_{7} + 2*0.14829620853763437Z_{1}Z_{2}Z_{5}Z_{7} + 2*0.1495433382886273Z_{1}Z_{3} + 2*0.15009726426928754Z_{2}Z_{3} + 2*0.15148164714323517Z_{4}Z_{5} + 2*0.16090057412617417Z_{0}Z_{7} + 2*0.16638988040212221Z_{2}Z_{5}Z_{6}Z_{7} + 2*0.18038527181714664Z_{2}Z_{3}Z_{4}Z_{7} + 2*0.2238514152233495Z_{1}Z_{2} + 2*0.22591605022554492Z_{1}Z_{3}Z_{4}Z_{5} + 2*0.2267528696459229Z_{2}Z_{3}Z_{4}Z_{5} + 2*0.2274848302527393Z_{3}Z_{4}Z_{6}Z_{7} + 2*0.23222469488145225Z_{4}Z_{6} + 2*0.24906727115520388Z_{1}Z_{3}Z_{4}Z_{6} + 2*0.2531699312023235Z_{0}Z_{3} + 2*0.2690222142175258Z_{1}Z_{2}Z_{4}Z_{7} + 2*0.2698374439183693Z_{1}Z_{2}Z_{3}Z_{4} + 2*0.27001870390095273Z_{4}Z_{7} + 2*0.27250915081979443Z_{2}Z_{3}Z_{5}Z_{7} + 2*0.2927721488994552Z_{0}Z_{3}Z_{4}Z_{5} + 2*0.3027604040881304Z_{2}Z_{3}Z_{4}Z_{6} + 2*0.33926535198242647Z_{1}Z_{4}Z_{6}Z_{7} + 2*0.34052203044735546Z_{2}Z_{4}Z_{6}Z_{7} + 2*0.34366274636545135Z_{3}Z_{5}Z_{6}Z_{7} + 2*0.34633427099484043Z_{1}Z_{3}Z_{4}Z_{6} + 2*0.34761713356092017Z_{2}Z_{3}Z_{4}Z_{6} + 2*0.35082328930756407Z_{5}Z_{6} + 2*0.3714528802729042Z_{4}Z_{6} + 2*0.3728287850997519Z_{1}Z_{2}Z_{4}Z_{6} + 2*0.37626747392275944Z_{1}Z_{3}Z_{5}Z_{6} + 2*0.3775714878451272Z_{0}Z_{1} + 2*0.37897005670862477Z_{0}Z_{2} + 2*0.38246538794467677Z_{0}Z_{3}Z_{4}Z_{5} + 2*0.4024290115841755Z_{2}Z_{4} + 2*0.4039196556171291Z_{1}Z_{4} + 2*0.4076451029556227Z_{1}Z_{2}Z_{3}Z_{5} + 2*0.4092357000709275Z_{2}Z_{6} + 2*0.4177625183973087Z_{2}Z_{3}Z_{6}Z_{7} + 2*0.43663327368541743Z_{0}Z_{1}Z_{4}Z_{5} + 2*0.43825061429773066Z_{0}Z_{2}Z_{4}Z_{5} + 2*0.44229270425776035Z_{0}Z_{3} + 2*0.44806160904317277Z_{1}Z_{2}Z_{6}Z_{7} + 2*0.4515295149359277Z_{1}Z_{2}Z_{4}Z_{6} + 2*0.45320203296461575Z_ ...

# %%
cost_hamil_squared.n_qubits
cost_hamil.n_qubits
# Out:
# 8

# %% [markdown]
# ## Constructing Mixer Hamiltonians

# %% [markdown]
# ### X-mixer hamiltonian

# %%
from openqaoa.utilities import X_mixer_hamiltonian, XY_mixer_hamiltonian

# %%
rx_mixer = X_mixer_hamiltonian(cost_hamil.n_qubits)

# %%
xy_mixer_full = XY_mixer_hamiltonian(cost_hamil.n_qubits,'full')
xy_mixer_star = XY_mixer_hamiltonian(cost_hamil.n_qubits,'star')
xy_mixer_chain = XY_mixer_hamiltonian(cost_hamil.n_qubits,'chain')

# %%
rx_mixer.expression
# Out:
# -1X_{0} - 1X_{1} - 1X_{2} - 1X_{3} - 1X_{4} - 1X_{5} - 1X_{6} - 1X_{7} + 0

# %%
xy_mixer_full.expression
xy_mixer_chain.expression
xy_mixer_star.expression
# Out:
# 0 + 0.5X_{0}X_{1} + 0.5X_{0}X_{2} + 0.5X_{0}X_{3} + 0.5X_{0}X_{4} + 0.5X_{0}X_{5} + 0.5X_{0}X_{6} + 0.5X_{0}X_{7} + 0.5Y_{0}Y_{1} + 0.5Y_{0}Y_{2} + 0.5Y_{0}Y_{3} + 0.5Y_{0}Y_{4} + 0.5Y_{0}Y_{5} + 0.5Y_{0}Y_{6} + 0.5Y_{0}Y_{7}

# %%
print("Terms:", '\n', 
      '\t',rx_mixer.terms)
print("Coefficients: ",'\n',
      '\t',rx_mixer.coeffs)
print("Constant: ", rx_mixer.constant)
# Out:
# Terms:
#  	 [PauliOp(X,(0,)), PauliOp(X,(1,)), PauliOp(X,(2,)), PauliOp(X,(3,)), PauliOp(X,(4,)), PauliOp(X,(5,)), PauliOp(X,(6,)), PauliOp(X,(7,))]
# Coefficients:
#  	 [-1, -1, -1, -1, -1, -1, -1, -1]
# Constant:  0

# %%
print("Terms:", '\n', 
      '\t',xy_mixer_chain.terms)
print("Coefficients: ",'\n',
      '\t',xy_mixer_chain.coeffs)
print("Constant: ", xy_mixer_chain.constant)
# Out:
# Terms:
#  	 [PauliOp(XX,(0, 1)), PauliOp(YY,(0, 1)), PauliOp(XX,(1, 2)), PauliOp(YY,(1, 2)), PauliOp(XX,(2, 3)), PauliOp(YY,(2, 3)), PauliOp(XX,(3, 4)), PauliOp(YY,(3, 4)), PauliOp(XX,(4, 5)), PauliOp(YY,(4, 5)), PauliOp(XX,(5, 6)), PauliOp(YY,(5, 6)), PauliOp(XX,(6, 7)), PauliOp(YY,(6, 7))]
# Coefficients:
#  	 [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5]
# Constant:  0
