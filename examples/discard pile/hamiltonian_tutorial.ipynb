# %%
from openqaoa.qaoa_parameters.operators import PauliOp, Hamiltonian
from openqaoa.utilities import *

# %%
import networkx as nx
from networkx import fast_gnp_random_graph as gnp
from openqaoa.utilities import random_k_regular_graph

# %% [markdown]
# ## Constructing the Cost Hamiltonian and its squared (to compute uncertainty in expectation value)

# %%
# gr = gnp(10,0.5)
gr = random_k_regular_graph(4,[0,1,2,3,4,5,6,7],weighted=True,biases=True)

# %%
terms_list=list(nx.get_edge_attributes(gr,'weight').keys())
coeffs_list=list(nx.get_edge_attributes(gr,'weight').values())

# %%
cost_hamil = Hamiltonian.classical_hamiltonian(terms_list,coeffs_list,constant=0)

# %%
cost_hamil.expression
# Out:
# 0 + 0.01951161660529932Z_{5}Z_{7} + 0.019679743914105652Z_{0}Z_{6} + 0.04954300553905966Z_{2}Z_{6} + 0.21820396590191093Z_{0}Z_{5} + 0.30231269237924263Z_{0}Z_{3} + 0.3649130616395325Z_{1}Z_{5} + 0.4253041797099534Z_{4}Z_{7} + 0.5594299647818592Z_{2}Z_{3} + 0.5657784994881466Z_{1}Z_{2} + 0.5915070241954172Z_{4}Z_{6} + 0.6384286059652233Z_{1}Z_{4} + 0.6766639997342976Z_{1}Z_{6} + 0.7056730785701397Z_{3}Z_{7} + 0.7108895946114134Z_{2}Z_{7} + 0.8230569997021792Z_{0}Z_{4} + 0.8459534975030795Z_{3}Z_{5}

# %%
len(cost_hamil)
# Out:
# 16

# %%
cost_hamil_squared = cost_hamil.hamiltonian_squared

# %%
cost_hamil_squared.expression
# Out:
# 2*0.0003839836181425021Z_{0}Z_{5}Z_{6}Z_{7} + 2*0.0009666641295523527Z_{2}Z_{5}Z_{6}Z_{7} + 2*0.0009749936617438119Z_{0}Z_{2} + 2*0.004257512124433892Z_{0}Z_{7} + 2*0.004294198169991849Z_{5}Z_{6} + 2*0.005898609348619576Z_{0}Z_{3}Z_{5}Z_{7} + 2*0.0059494363680072946Z_{3}Z_{6} + 2*0.0071200437529765175Z_{1}Z_{7} + 2*0.00718139560397825Z_{0}Z_{1}Z_{5}Z_{6} + 2*0.008298372095131932Z_{4}Z_{5} + 2*0.008369877342290652Z_{0}Z_{4}Z_{6}Z_{7} + 2*0.010810480291323159Z_{0}Z_{2}Z_{5}Z_{6} + 2*0.010915382990339739Z_{2}Z_{3}Z_{5}Z_{7} + 2*0.011009438444784133Z_{0}Z_{2}Z_{3}Z_{6} + 2*0.011039253165534255Z_{1}Z_{2}Z_{5}Z_{7} + 2*0.011134375982033682Z_{0}Z_{1}Z_{2}Z_{6} + 2*0.011541258275442489Z_{4}Z_{5}Z_{6}Z_{7} + 2*0.011640706759560507Z_{0}Z_{4} + 2*0.012456774189449148Z_{1}Z_{4}Z_{5}Z_{7} + 2*0.012564111472835059Z_{0}Z_{1}Z_{4}Z_{6} + 2*0.013202808533423975Z_{1}Z_{5}Z_{6}Z_{7} + 2*0.01331657423066543Z_{0}Z_{1} + 2*0.01376882255774183Z_{3}Z_{5} + 2*0.013870605218754556Z_{2}Z_{5} + 2*0.013887465473338906Z_{0}Z_{3}Z_{6}Z_{7} + 2*0.013990125173154998Z_{0}Z_{2}Z_{6}Z_{7} + 2*0.014977479393072856Z_{0}Z_{2}Z_{3}Z_{6} + 2*0.016059172622496877Z_{0}Z_{4}Z_{5}Z_{7} + 2*0.016197550980851017Z_{4}Z_{6} + 2*0.016505920309192124Z_{3}Z_{7} + 2*0.016648148194102617Z_{0}Z_{3}Z_{5}Z_{6} + 2*0.018078889834082578Z_{1}Z_{2}Z_{5}Z_{6} + 2*0.021070847331155444Z_{2}Z_{4}Z_{6}Z_{7} + 2*0.0277158418439036Z_{3}Z_{6} + 2*0.02803036733402211Z_{1}Z_{6} + 2*0.029305035776106252Z_{2}Z_{4} + 2*0.0316296719616292Z_{1}Z_{2}Z_{4}Z_{6} + 2*0.033523968286918567Z_{1}Z_{2} + 2*0.034961165240365716Z_{2}Z_{3}Z_{6}Z_{7} + 2*0.03521960712349313Z_{6}Z_{7} + 2*0.040776717495206886Z_{0}Z_{2}Z_{4}Z_{6} + 2*0.04191107881258196Z_{2}Z_{3}Z_{5}Z_{6} + 2*0.06596582841963515Z_{3}Z_{5} + 2*0.07962547725915448Z_{0}Z_{1} + 2*0.09280305872737087Z_{0}Z_{4}Z_{5}Z_{7} + 0.0Z_{0}Z_{3} + 0.0Z_{0}Z_{4} + 0.0Z_{0}Z_{5} + 0.0Z_{0}Z_{6} + 0.0Z_{1}Z_{2} + 0.0Z_{1}Z_{4} + 0.0Z_{1}Z_{5} + 0.0Z_{1}Z_{6} + 0.0Z_{2}Z_{3} + 0.0Z_{2}Z_{6} + 0.0Z_{2}Z_{7} + 0.0Z_{3}Z_{5} + 0.0Z_{3}Z_{7} + 0.0Z_{4}Z_{6} + 0.0Z_{4}Z_{7} + 0.0Z_{5}Z_{7} + 2*0.1103178501485996Z_{0}Z_{1}Z_{3}Z_{5} + 2*0.12206983695976804Z_{0}Z_{2}Z_{3}Z_{5} + 2*0.12345511241034587Z_{0}Z_{1}Z_{2}Z_{5} + 2*0.12857485164826127Z_{0}Z_{3}Z_{4}Z_{7} + 2*0.12906917853827762Z_{0}Z_{4}Z_{5}Z_{6} + 2*0.13930765376684012Z_{0}Z_{1}Z_{4}Z_{5} + 2*0.14765076832507334Z_{0}Z_{1}Z_{5}Z_{6} + 2*0.1539806643742153Z_{0}Z_{3}Z_{5}Z_{7} + 2*0.15511892886261214Z_{0}Z_{2}Z_{5}Z_{7} + 2*0.15519905034604903Z_{1}Z_{4}Z_{5}Z_{7} + 2*0.16912277885082874Z_{0}Z_{2} + 2*0.17104202147054956Z_{0}Z_{1}Z_{2}Z_{3} + 2*0.1788200810457504Z_{0}Z_{3}Z_{4}Z_{6} + 2*0.1795943014983434Z_{4}Z_{5} + 2*0.18459040812376426Z_{0}Z_{3} + 2*0.19300507076127327Z_{0}Z_{1}Z_{3}Z_{4} + 2*0.2041433012214441Z_{1}Z_{2}Z_{3}Z_{5} + 2*0.20456411559578264Z_{0}Z_{1}Z_{3}Z_{6} + 2*0.20645996445804027Z_{2}Z_{5} + 2*0.21333392832208778Z_{0}Z_{7} + 2*0.21491094733136473Z_{0}Z_{2}Z_{3}Z_{7} + 2*0.21584863918043873Z_{1}Z_{4}Z_{5}Z_{6} + 2*0.23297093724102835Z_{4}Z_{5} + 2*0.23792790227671676Z_{2}Z_{3}Z_{4}Z_{7} + 2*0.24062796062233446Z_{1}Z_{2}Z_{4}Z_{7} + 2*0.24692353184429436Z_{5}Z_{6} + 2*0.2488205775615473Z_{3}Z_{4} + 2*0.25157040971810746Z_{6}Z_{7} + 2*0.2557424794577929Z_{0}Z_{5} + 2*0.2575093236176241Z_{1}Z_{3}Z_{5}Z_{7} + 2*0.259412898457337Z_{1}Z_{2}Z_{5}Z_{7} + 2*0.27152635456340835Z_{1}Z_{7} + 2*0.28778802734625153Z_{1}Z_{4}Z_{6}Z_{7} + 2*0.30012570982467074Z_{3}Z_{4} + 2*0.30034424966517Z_{0}Z_{1}Z_{4}Z_{5} + 2*0.3023443159005485Z_{2}Z_{4} + 2*0.30869948077851933Z_{1}Z_{3} + 2*0.31651344604298703Z_{1}Z_{3} + 2*0.33090675371386463Z_{2}Z_{3}Z_{4}Z_{6} + 2*0.334661956585982Z_{1}Z_{2}Z_{4}Z_{6} + 2*0.3500495821128706Z_{0}Z_{7} + 2*0.3571560925508564Z_{1}Z_{2}Z_{3}Z_{4} + 2*0.35978755832831333Z_{3}Z_{4}Z_{5}Z_{7} + 2*0.36120917871331326Z_{2}Z_{4} + 2*0.37763500487571783Z_{1}Z_{6} + 2*0.3785461175405101Z_{1}Z_{2}Z_{3}Z_{6} + 2*0.38284194242731856Z_{2}Z_{6} + 2*0.39477466549199947Z_{2}Z_{7} + 2*0.3976929408772532Z_{3 ...

# %%
cost_hamil_squared.n_qubits
cost_hamil.n_qubits
# Out:
# 8

# %% [markdown]
# ## Constructing Mixer Hamiltonians

# %% [markdown]
# ### X-mixer hamiltonian

# %%
from openqaoa.utilities import X_mixer_hamiltonian, XY_mixer_hamiltonian

# %%
rx_mixer = X_mixer_hamiltonian(cost_hamil.n_qubits)

# %%
xy_mixer_full = XY_mixer_hamiltonian(cost_hamil.n_qubits,'full')
xy_mixer_star = XY_mixer_hamiltonian(cost_hamil.n_qubits,'star')
xy_mixer_chain = XY_mixer_hamiltonian(cost_hamil.n_qubits,'chain')

# %%
rx_mixer.expression
# Out:
# -1X_{0} - 1X_{1} - 1X_{2} - 1X_{3} - 1X_{4} - 1X_{5} - 1X_{6} - 1X_{7} + 0

# %%
xy_mixer_full.expression
xy_mixer_chain.expression
xy_mixer_star.expression
# Out:
# 0 + 0.5X_{0}X_{1} + 0.5X_{0}X_{2} + 0.5X_{0}X_{3} + 0.5X_{0}X_{4} + 0.5X_{0}X_{5} + 0.5X_{0}X_{6} + 0.5X_{0}X_{7} + 0.5Y_{0}Y_{1} + 0.5Y_{0}Y_{2} + 0.5Y_{0}Y_{3} + 0.5Y_{0}Y_{4} + 0.5Y_{0}Y_{5} + 0.5Y_{0}Y_{6} + 0.5Y_{0}Y_{7}

# %%
print("Terms:", '\n', 
      '\t',rx_mixer.terms)
print("Coefficients: ",'\n',
      '\t',rx_mixer.coeffs)
print("Constant: ", rx_mixer.constant)
# Out:
# Terms:
#  	 [PauliOp(X,(0,)), PauliOp(X,(1,)), PauliOp(X,(2,)), PauliOp(X,(3,)), PauliOp(X,(4,)), PauliOp(X,(5,)), PauliOp(X,(6,)), PauliOp(X,(7,))]
# Coefficients:
#  	 [-1, -1, -1, -1, -1, -1, -1, -1]
# Constant:  0

# %%
print("Terms:", '\n', 
      '\t',xy_mixer_chain.terms)
print("Coefficients: ",'\n',
      '\t',xy_mixer_chain.coeffs)
print("Constant: ", xy_mixer_chain.constant)
# Out:
# Terms:
#  	 [PauliOp(XX,(0, 1)), PauliOp(YY,(0, 1)), PauliOp(XX,(1, 2)), PauliOp(YY,(1, 2)), PauliOp(XX,(2, 3)), PauliOp(YY,(2, 3)), PauliOp(XX,(3, 4)), PauliOp(YY,(3, 4)), PauliOp(XX,(4, 5)), PauliOp(YY,(4, 5)), PauliOp(XX,(5, 6)), PauliOp(YY,(5, 6)), PauliOp(XX,(6, 7)), PauliOp(YY,(6, 7))]
# Coefficients:
#  	 [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5]
# Constant:  0
