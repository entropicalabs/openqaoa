# %%
from openqaoa.qaoa_parameters.operators import PauliOp, Hamiltonian
from openqaoa.utilities import *

# %%
import networkx as nx
from networkx import fast_gnp_random_graph as gnp
from openqaoa.utilities import random_k_regular_graph

# %% [markdown]
# ## Constructing the Cost Hamiltonian and its squared (to compute uncertainty in expectation value)

# %%
# gr = gnp(10,0.5)
gr = random_k_regular_graph(4,[0,1,2,3,4,5,6,7],weighted=True,biases=True)

# %%
terms_list=list(nx.get_edge_attributes(gr,'weight').keys())
coeffs_list=list(nx.get_edge_attributes(gr,'weight').values())

# %%
cost_hamil = Hamiltonian.classical_hamiltonian(terms_list,coeffs_list,constant=0)

# %%
cost_hamil.expression
# Out:
# 0 + 0.0025286495237586415Z_{5}Z_{7} + 0.036909114875575355Z_{3}Z_{6} + 0.11975167892825844Z_{1}Z_{3} + 0.1408325971771467Z_{1}Z_{6} + 0.2637459185616706Z_{2}Z_{3} + 0.3213067182273286Z_{4}Z_{5} + 0.321513539060829Z_{4}Z_{7} + 0.3865075539280417Z_{1}Z_{2} + 0.49052471326183544Z_{1}Z_{7} + 0.5135809040074122Z_{2}Z_{7} + 0.5287392112554467Z_{0}Z_{4} + 0.5738836555471211Z_{0}Z_{5} + 0.7851412376153248Z_{0}Z_{3} + 0.8209379547433373Z_{0}Z_{2} + 0.8881291695238451Z_{5}Z_{6} + 0.9032835165043255Z_{4}Z_{6}

# %%
len(cost_hamil)
# Out:
# 16

# %%
cost_hamil_squared = cost_hamil.hamiltonian_squared

# %%
cost_hamil_squared.expression
# Out:
# 2*0.00030281002589123846Z_{1}Z_{3}Z_{5}Z_{7} + 2*0.0003561162797816846Z_{1}Z_{5}Z_{6}Z_{7} + 2*0.0006669209913642539Z_{2}Z_{3}Z_{5}Z_{7} + 2*0.0008124720800259864Z_{4}Z_{7} + 2*0.0008129950574281207Z_{4}Z_{5} + 2*0.00097734214216926Z_{1}Z_{2}Z_{5}Z_{7} + 2*0.0012403650825813844Z_{1}Z_{5} + 2*0.0012986661083298754Z_{2}Z_{5} + 2*0.0013369961547336049Z_{0}Z_{4}Z_{5}Z_{7} + 2*0.0014511506322920959Z_{0}Z_{7} + 2*0.0019853470165792616Z_{0}Z_{3}Z_{5}Z_{7} + 2*0.002075864368297133Z_{0}Z_{2}Z_{5}Z_{7} + 2*0.002245767401552629Z_{6}Z_{7} + 2*0.0022840874338276936Z_{4}Z_{5}Z_{6}Z_{7} + 2*0.004419928474106108Z_{1}Z_{6} + 2*0.005198006507436937Z_{1}Z_{3} + 2*0.009734628406156843Z_{2}Z_{6} + 2*0.011859146573346593Z_{3}Z_{4}Z_{5}Z_{6} + 2*0.011866780147248922Z_{3}Z_{4}Z_{6}Z_{7} + 2*0.014265651708207728Z_{1}Z_{2}Z_{3}Z_{6} + 2*0.016864939959790427Z_{3}Z_{6} + 2*0.018104832991089746Z_{1}Z_{3}Z_{6}Z_{7} + 2*0.018955816583911416Z_{2}Z_{3}Z_{6}Z_{7} + 2*0.019515296287448386Z_{0}Z_{3}Z_{4}Z_{6} + 2*0.02118153776780381Z_{0}Z_{3}Z_{5}Z_{6} + 2*0.02897886813269543Z_{0}Z_{6} + 2*0.03030009327734172Z_{0}Z_{2}Z_{3}Z_{6} + 2*0.031584016558235777Z_{1}Z_{2} + 2*0.032780061542304936Z_{3}Z_{5} + 2*0.03333939507587182Z_{3}Z_{4} + 2*0.03714402270591229Z_{1}Z_{2}Z_{3}Z_{6} + 2*0.03847701895865146Z_{1}Z_{3}Z_{4}Z_{5} + 2*0.03850178610070048Z_{1}Z_{3}Z_{4}Z_{7} + 2*0.04525045961842034Z_{1}Z_{4}Z_{5}Z_{6} + 2*0.04527958673355255Z_{1}Z_{4}Z_{6}Z_{7} + 2*0.046284928501337384Z_{2}Z_{3} + 2*0.0544328626482722Z_{2}Z_{6} + 2*0.05874115796890735Z_{3}Z_{7} + 2*0.06150217552038034Z_{1}Z_{2}Z_{3}Z_{7} + 2*0.06331740826304286Z_{0}Z_{1}Z_{3}Z_{4} + 2*0.0687235312612541Z_{0}Z_{1}Z_{3}Z_{5} + 2*0.06908186934823946Z_{6}Z_{7} + 2*0.07232893257195072Z_{1}Z_{2}Z_{6}Z_{7} + 2*0.07446371635050059Z_{0}Z_{1}Z_{4}Z_{6} + 2*0.0808215256882161Z_{0}Z_{1}Z_{5}Z_{6} + 2*0.08474333553890266Z_{2}Z_{3}Z_{4}Z_{5} + 2*0.08479788368961191Z_{2}Z_{3}Z_{4}Z_{7} + 2*0.09402198140024585Z_{0}Z_{1} + 2*0.09830869837644529Z_{0}Z_{1}Z_{2}Z_{3} + 0.0Z_{0}Z_{2} + 0.0Z_{0}Z_{3} + 0.0Z_{0}Z_{4} + 0.0Z_{0}Z_{5} + 0.0Z_{1}Z_{2} + 0.0Z_{1}Z_{3} + 0.0Z_{1}Z_{6} + 0.0Z_{1}Z_{7} + 0.0Z_{2}Z_{3} + 0.0Z_{2}Z_{7} + 0.0Z_{3}Z_{6} + 0.0Z_{4}Z_{5} + 0.0Z_{4}Z_{6} + 0.0Z_{4}Z_{7} + 0.0Z_{5}Z_{6} + 0.0Z_{5}Z_{7} + 2*0.1019397898417758Z_{1}Z_{3} + 2*0.10330446010128899Z_{5}Z_{7} + 2*0.10635495915564032Z_{1}Z_{3}Z_{5}Z_{6} + 2*0.10816971764961422Z_{1}Z_{3}Z_{4}Z_{6} + 2*0.11057347964424545Z_{0}Z_{1}Z_{3}Z_{6} + 2*0.11561482428779911Z_{0}Z_{1}Z_{2}Z_{6} + 2*0.1241874737226913Z_{1}Z_{2}Z_{4}Z_{5} + 2*0.12426741153714892Z_{1}Z_{2}Z_{4}Z_{7} + 2*0.1250775375728255Z_{1}Z_{5} + 2*0.1272117636166102Z_{1}Z_{4} + 2*0.12937389107644287Z_{1}Z_{2}Z_{3}Z_{7} + 2*0.1354548672831681Z_{3}Z_{7} + 2*0.139452808952141Z_{0}Z_{2}Z_{3}Z_{4} + 2*0.15135947187980484Z_{0}Z_{2}Z_{3}Z_{5} + 2*0.15760888582756172Z_{1}Z_{4}Z_{5}Z_{7} + 2*0.15771033655761107Z_{1}Z_{4} + 2*0.16501699481084628Z_{2}Z_{4}Z_{5}Z_{7} + 2*0.165123214041483Z_{2}Z_{4} + 2*0.16988746076659375Z_{0}Z_{5} + 2*0.16999681505096997Z_{0}Z_{7} + 2*0.18439267400814813Z_{0}Z_{4} + 2*0.18451136510412067Z_{0}Z_{4}Z_{5}Z_{7} + 2*0.18959150706408606Z_{2}Z_{7} + 2*0.19850289895205728Z_{1}Z_{7} + 2*0.20436169920818478Z_{0}Z_{1}Z_{2}Z_{4} + 2*0.20707779691550074Z_{0}Z_{2} + 2*0.21651903495592068Z_{0}Z_{3} + 2*0.2218103679448006Z_{0}Z_{1}Z_{2}Z_{5} + 2*0.23424044361748023Z_{2}Z_{3}Z_{5}Z_{6} + 2*0.23823734078204928Z_{2}Z_{3}Z_{4}Z_{6} + 2*0.2519241256749901Z_{1}Z_{2} + 2*0.2522711544031232Z_{0}Z_{3}Z_{4}Z_{5} + 2*0.25243353796830237Z_{0}Z_{3}Z_{4}Z_{7} + 2*0.259359649991367Z_{0}Z_{1}Z_{4}Z_{7} + 2*0.2637728801068369Z_{0}Z_{2}Z_{4}Z_{5} + 2*0.2639426671788891Z_{0}Z_{2}Z_{4}Z_{7} + 2*0.2715503621007384Z_{0}Z_{2}Z_{4}Z_{7} + 2*0.2815041155829055Z_{0}Z_{1}Z_{5}Z_{7} + 2*0.2853618688216695Z_{4}Z_{6} + 2*0.28554555243676644Z_{4}Z_{5}Z_{6}Z_{7} + 2*0.2902310623168458Z_{5}Z_{6} + 2*0.29041788016661646Z_{6}Z_{7} + 2*0.2947356866109688Z_{0}Z_{2}Z_{5}Z_{7} + 2*0.30343479138637725Z_{4}Z_{5} + 2*0.30346301923873 ...

# %%
cost_hamil_squared.n_qubits
cost_hamil.n_qubits
# Out:
# 8

# %% [markdown]
# ## Constructing Mixer Hamiltonians

# %% [markdown]
# ### X-mixer hamiltonian

# %%
from openqaoa.utilities import X_mixer_hamiltonian, XY_mixer_hamiltonian

# %%
rx_mixer = X_mixer_hamiltonian(cost_hamil.n_qubits)

# %%
xy_mixer_full = XY_mixer_hamiltonian(cost_hamil.n_qubits,'full')
xy_mixer_star = XY_mixer_hamiltonian(cost_hamil.n_qubits,'star')
xy_mixer_chain = XY_mixer_hamiltonian(cost_hamil.n_qubits,'chain')

# %%
rx_mixer.expression
# Out:
# -1X_{0} - 1X_{1} - 1X_{2} - 1X_{3} - 1X_{4} - 1X_{5} - 1X_{6} - 1X_{7} + 0

# %%
xy_mixer_full.expression
xy_mixer_chain.expression
xy_mixer_star.expression
# Out:
# 0 + 0.5X_{0}X_{1} + 0.5X_{0}X_{2} + 0.5X_{0}X_{3} + 0.5X_{0}X_{4} + 0.5X_{0}X_{5} + 0.5X_{0}X_{6} + 0.5X_{0}X_{7} + 0.5Y_{0}Y_{1} + 0.5Y_{0}Y_{2} + 0.5Y_{0}Y_{3} + 0.5Y_{0}Y_{4} + 0.5Y_{0}Y_{5} + 0.5Y_{0}Y_{6} + 0.5Y_{0}Y_{7}

# %%
print("Terms:", '\n', 
      '\t',rx_mixer.terms)
print("Coefficients: ",'\n',
      '\t',rx_mixer.coeffs)
print("Constant: ", rx_mixer.constant)
# Out:
# Terms:
#  	 [PauliOp(X,(0,)), PauliOp(X,(1,)), PauliOp(X,(2,)), PauliOp(X,(3,)), PauliOp(X,(4,)), PauliOp(X,(5,)), PauliOp(X,(6,)), PauliOp(X,(7,))]
# Coefficients:
#  	 [-1, -1, -1, -1, -1, -1, -1, -1]
# Constant:  0

# %%
print("Terms:", '\n', 
      '\t',xy_mixer_chain.terms)
print("Coefficients: ",'\n',
      '\t',xy_mixer_chain.coeffs)
print("Constant: ", xy_mixer_chain.constant)
# Out:
# Terms:
#  	 [PauliOp(XX,(0, 1)), PauliOp(YY,(0, 1)), PauliOp(XX,(1, 2)), PauliOp(YY,(1, 2)), PauliOp(XX,(2, 3)), PauliOp(YY,(2, 3)), PauliOp(XX,(3, 4)), PauliOp(YY,(3, 4)), PauliOp(XX,(4, 5)), PauliOp(YY,(4, 5)), PauliOp(XX,(5, 6)), PauliOp(YY,(5, 6)), PauliOp(XX,(6, 7)), PauliOp(YY,(6, 7))]
# Coefficients:
#  	 [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5]
# Constant:  0
