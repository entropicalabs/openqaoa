# %%
from openqaoa.qaoa_parameters.operators import PauliOp, Hamiltonian
from openqaoa.utilities import *

# %%
import networkx as nx
from networkx import fast_gnp_random_graph as gnp
from openqaoa.utilities import random_k_regular_graph

# %% [markdown]
# ## Constructing the Cost Hamiltonian and its squared (to compute uncertainty in expectation value)

# %%
# gr = gnp(10,0.5)
gr = random_k_regular_graph(4,[0,1,2,3,4,5,6,7],weighted=True,biases=True)

# %%
terms_list=list(nx.get_edge_attributes(gr,'weight').keys())
coeffs_list=list(nx.get_edge_attributes(gr,'weight').values())

# %%
cost_hamil = Hamiltonian.classical_hamiltonian(terms_list,coeffs_list,constant=0)

# %%
cost_hamil.expression
# Out:
# 0 + 0.030536145642465762Z_{3}Z_{5} + 0.1386491044268786Z_{0}Z_{1} + 0.19092931449522887Z_{6}Z_{7} + 0.23128032338971471Z_{4}Z_{7} + 0.24256293918223248Z_{0}Z_{7} + 0.31341110731644484Z_{0}Z_{4} + 0.3424390860811103Z_{0}Z_{5} + 0.36354325391560205Z_{2}Z_{3} + 0.42910554799643297Z_{2}Z_{5} + 0.44323925557867483Z_{4}Z_{6} + 0.4645433985122145Z_{1}Z_{6} + 0.527558289823231Z_{2}Z_{6} + 0.7205343382085853Z_{2}Z_{7} + 0.8339648676505802Z_{1}Z_{5} + 0.8720710047705708Z_{3}Z_{4} + 0.9970952217229492Z_{1}Z_{3}

# %%
len(cost_hamil)
# Out:
# 16

# %%
cost_hamil_squared = cost_hamil.hamiltonian_squared

# %%
cost_hamil_squared.expression
# Out:
# 2*0.00423380924597661Z_{0}Z_{1}Z_{3}Z_{5} + 2*0.005830245354842458Z_{3}Z_{5}Z_{6}Z_{7} + 2*0.007062409639264909Z_{3}Z_{4}Z_{5}Z_{7} + 2*0.007406937238333216Z_{0}Z_{3}Z_{5}Z_{7} + 2*0.009570367218981427Z_{0}Z_{3}Z_{4}Z_{5} + 2*0.010456769806245653Z_{0}Z_{3} + 2*0.011101209748902736Z_{2}Z_{5} + 2*0.01310322950960916Z_{2}Z_{3} + 2*0.01353481846280852Z_{3}Z_{4}Z_{5}Z_{6} + 2*0.014185364874214994Z_{1}Z_{3}Z_{5}Z_{6} + 2*0.016109596772932347Z_{2}Z_{3}Z_{5}Z_{6} + 2*0.022002341491935043Z_{2}Z_{3}Z_{5}Z_{7} + 2*0.025466072659277802Z_{1}Z_{3} + 2*0.026472178463601337Z_{0}Z_{1}Z_{6}Z_{7} + 2*0.026629687212245602Z_{4}Z_{5} + 2*0.030447444909938667Z_{1}Z_{5} + 2*0.03206680970954281Z_{0}Z_{1}Z_{4}Z_{7} + 2*0.03363113428476796Z_{1}Z_{7} + 2*0.04345416934686142Z_{1}Z_{4} + 2*0.04415819360103308Z_{4}Z_{6} + 2*0.04631237570001154Z_{0}Z_{6} + 2*0.047478872605904734Z_{1}Z_{5} + 2*0.050404946575831555Z_{0}Z_{1}Z_{2}Z_{3} + 2*0.05610003501642643Z_{0}Z_{4} + 2*0.05949509993431041Z_{0}Z_{1}Z_{2}Z_{5} + 2*0.059839367875119426Z_{0}Z_{4}Z_{6}Z_{7} + 2*0.06145472583281963Z_{0}Z_{1}Z_{4}Z_{6} + 2*0.06440852617113711Z_{0}Z_{6} + 2*0.06538165996183906Z_{0}Z_{5}Z_{6}Z_{7} + 2*0.06941106425947083Z_{2}Z_{3}Z_{6}Z_{7} + 2*0.07248582225407595Z_{0}Z_{7} + 2*0.07314548441696665Z_{0}Z_{1}Z_{2}Z_{6} + 2*0.07602191936303494Z_{4}Z_{7} + 2*0.07919942257011754Z_{0}Z_{4}Z_{5}Z_{7} + 2*0.08192882812505847Z_{2}Z_{5}Z_{6}Z_{7} + 2*0.08306303121071162Z_{5}Z_{7} + 2*0.08408040133174961Z_{2}Z_{3}Z_{4}Z_{7} + 2*0.08462736722501193Z_{4}Z_{7} + 2*0.08818212018964108Z_{0}Z_{2}Z_{3}Z_{7} + 2*0.08869495263122104Z_{1}Z_{7} + 2*0.09924366990893577Z_{2}Z_{4}Z_{5}Z_{7} + 2*0.099901440701434Z_{0}Z_{1}Z_{2}Z_{7} + 0.0Z_{0}Z_{1} + 0.0Z_{0}Z_{4} + 0.0Z_{0}Z_{5} + 0.0Z_{0}Z_{7} + 0.0Z_{1}Z_{3} + 0.0Z_{1}Z_{5} + 0.0Z_{1}Z_{6} + 0.0Z_{2}Z_{3} + 0.0Z_{2}Z_{5} + 0.0Z_{2}Z_{6} + 0.0Z_{2}Z_{7} + 0.0Z_{3}Z_{4} + 0.0Z_{3}Z_{5} + 0.0Z_{4}Z_{6} + 0.0Z_{4}Z_{7} + 0.0Z_{6}Z_{7} + 2*0.10072634263222478Z_{2}Z_{7} + 2*0.10251251836925232Z_{6}Z_{7} + 2*0.10408510294141732Z_{0}Z_{2}Z_{5}Z_{7} + 2*0.10732421315711214Z_{4}Z_{5} + 2*0.10743974743646209Z_{1}Z_{4}Z_{6}Z_{7} + 2*0.1075134165941081Z_{0}Z_{4}Z_{6}Z_{7} + 2*0.11268101212082587Z_{0}Z_{1}Z_{6}Z_{7} + 2*0.1139384937671123Z_{0}Z_{2}Z_{3}Z_{4} + 2*0.1156284820232333Z_{0}Z_{5} + 2*0.12091186380808781Z_{0}Z_{1}Z_{3}Z_{4} + 2*0.12201385187724172Z_{2}Z_{4}Z_{6}Z_{7} + 2*0.12449141962181179Z_{0}Z_{2}Z_{3}Z_{5} + 2*0.12796608936947498Z_{0}Z_{2}Z_{6}Z_{7} + 2*0.13448644495319192Z_{0}Z_{2}Z_{4}Z_{5} + 2*0.13757112726443857Z_{2}Z_{6} + 2*0.13824635952020686Z_{0}Z_{3} + 2*0.13891610589702919Z_{0}Z_{6} + 2*0.14559306092425767Z_{0}Z_{1}Z_{4}Z_{6} + 2*0.14694251168823252Z_{0}Z_{2} + 2*0.1517824455956331Z_{0}Z_{4}Z_{5}Z_{6} + 2*0.1559984271918608Z_{3}Z_{5} + 2*0.15907781683153574Z_{0}Z_{1}Z_{5}Z_{6} + 2*0.15922834049362955Z_{1}Z_{5}Z_{6}Z_{7} + 2*0.1611366412362006Z_{2}Z_{3}Z_{4}Z_{6} + 2*0.16534262778746878Z_{0}Z_{2}Z_{4}Z_{6} + 2*0.16650391913201054Z_{3}Z_{4}Z_{6}Z_{7} + 2*0.16664541475427566Z_{2}Z_{4} + 2*0.1688816186801427Z_{1}Z_{2}Z_{3}Z_{6} + 2*0.1747749268575992Z_{0}Z_{2} + 2*0.18065657862158074Z_{0}Z_{2}Z_{5}Z_{6} + 2*0.19019642365861827Z_{2}Z_{4}Z_{5}Z_{6} + 2*0.19037470717003094Z_{1}Z_{3}Z_{6}Z_{7} + 2*0.19179025731248767Z_{3}Z_{6} + 2*0.19287966428588682Z_{1}Z_{4}Z_{5}Z_{7} + 2*0.19933814958670915Z_{1}Z_{2}Z_{5}Z_{6} + 2*0.20169286400213104Z_{3}Z_{7} + 2*0.20228896947204625Z_{0}Z_{1}Z_{5}Z_{7} + 2*0.20590387014054162Z_{1}Z_{4} + 2*0.21153210609275233Z_{0}Z_{3}Z_{4}Z_{7} + 2*0.22582346479747448Z_{0}Z_{2}Z_{4}Z_{7} + 2*0.22637818905465856Z_{5}Z_{6} + 2*0.23060850533042299Z_{1}Z_{3}Z_{4}Z_{7} + 2*0.2338345436556077Z_{2}Z_{4} + 2*0.24185834762567834Z_{0}Z_{1}Z_{3}Z_{7} + 2*0.24507372086777557Z_{1}Z_{2} + 2*0.24673912026620556Z_{0}Z_{2}Z_{5}Z_{7} + 2*0.2613738526333807Z_{0}Z_{1}Z_{4}Z_{5} + 2*0.261945397870274Z_{3}Z_{7} + 2*0.27331673926370925Z_{0}Z_{3} + 2*0.2855821671020188Z_{0}Z_{1} + 2*0.2986311978714698Z_{0}Z_{3}Z_{4}Z_{5} + 2*0.30318230163698634Z_{1}Z_{2}Z ...

# %%
cost_hamil_squared.n_qubits
cost_hamil.n_qubits
# Out:
# 8

# %% [markdown]
# ## Constructing Mixer Hamiltonians

# %% [markdown]
# ### X-mixer hamiltonian

# %%
from openqaoa.utilities import X_mixer_hamiltonian, XY_mixer_hamiltonian

# %%
rx_mixer = X_mixer_hamiltonian(cost_hamil.n_qubits)

# %%
xy_mixer_full = XY_mixer_hamiltonian(cost_hamil.n_qubits,'full')
xy_mixer_star = XY_mixer_hamiltonian(cost_hamil.n_qubits,'star')
xy_mixer_chain = XY_mixer_hamiltonian(cost_hamil.n_qubits,'chain')

# %%
rx_mixer.expression
# Out:
# -1X_{0} - 1X_{1} - 1X_{2} - 1X_{3} - 1X_{4} - 1X_{5} - 1X_{6} - 1X_{7} + 0

# %%
xy_mixer_full.expression
xy_mixer_chain.expression
xy_mixer_star.expression
# Out:
# 0 + 0.5X_{0}X_{1} + 0.5X_{0}X_{2} + 0.5X_{0}X_{3} + 0.5X_{0}X_{4} + 0.5X_{0}X_{5} + 0.5X_{0}X_{6} + 0.5X_{0}X_{7} + 0.5Y_{0}Y_{1} + 0.5Y_{0}Y_{2} + 0.5Y_{0}Y_{3} + 0.5Y_{0}Y_{4} + 0.5Y_{0}Y_{5} + 0.5Y_{0}Y_{6} + 0.5Y_{0}Y_{7}

# %%
print("Terms:", '\n', 
      '\t',rx_mixer.terms)
print("Coefficients: ",'\n',
      '\t',rx_mixer.coeffs)
print("Constant: ", rx_mixer.constant)
# Out:
# Terms:
#  	 [PauliOp(X,(0,)), PauliOp(X,(1,)), PauliOp(X,(2,)), PauliOp(X,(3,)), PauliOp(X,(4,)), PauliOp(X,(5,)), PauliOp(X,(6,)), PauliOp(X,(7,))]
# Coefficients:
#  	 [-1, -1, -1, -1, -1, -1, -1, -1]
# Constant:  0

# %%
print("Terms:", '\n', 
      '\t',xy_mixer_chain.terms)
print("Coefficients: ",'\n',
      '\t',xy_mixer_chain.coeffs)
print("Constant: ", xy_mixer_chain.constant)
# Out:
# Terms:
#  	 [PauliOp(XX,(0, 1)), PauliOp(YY,(0, 1)), PauliOp(XX,(1, 2)), PauliOp(YY,(1, 2)), PauliOp(XX,(2, 3)), PauliOp(YY,(2, 3)), PauliOp(XX,(3, 4)), PauliOp(YY,(3, 4)), PauliOp(XX,(4, 5)), PauliOp(YY,(4, 5)), PauliOp(XX,(5, 6)), PauliOp(YY,(5, 6)), PauliOp(XX,(6, 7)), PauliOp(YY,(6, 7))]
# Coefficients:
#  	 [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5]
# Constant:  0
