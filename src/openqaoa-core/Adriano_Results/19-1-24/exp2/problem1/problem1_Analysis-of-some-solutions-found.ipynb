# %% [markdown]
# ## Problem 1 - Analysis of some solutions found

# %% [markdown]
# We will consider to analyze the following solutions:
#
# * Solution with the lowest cost
# * Solution with the highest cost
# * Solution with lowest numer of iterations
# * Solution with the higher number of iterations

# %%
from openqaoa.problems import Knapsack

knapsack_prob = Knapsack(values=[4, 1, 4, 2, 2],weights=[4, 2, 4, 1, 3],weight_capacity=7,penalty=8)
print(knapsack_prob.problem_instance)
knapsack_qubo = knapsack_prob.qubo
knapsack_hamiltonian = knapsack_qubo.hamiltonian
# Out:
# {'problem_type': 'knapsack', 'values': [4, 1, 4, 2, 2], 'weights': [4, 2, 4, 1, 3], 'weight_capacity': 7, 'penalty': 8, 'n_items': 5}

# %% [markdown]
# ### Solution using brute force

# %%
from openqaoa.utilities import ground_state_hamiltonian
energy, configuration = ground_state_hamiltonian(knapsack_hamiltonian)
print(f"The solutions found with brute force are {configuration} with an energy of {energy}")
# Out:
# The solutions found with brute force are ['00011010', '00001110'] with an energy of -7.0

# %% [markdown]
# ### Solution with lowest cost:
# #### 4-standard-rand-x-Powell

# %%
import json
from openqaoa.algorithms import QAOAResult
from openqaoa.qaoa_components import Hamiltonian

with open('../../exp1/problem1/prob1_4-standard-rand-x-Powell.json', 'r') as file:
    data = json.load(file)
cost_hamiltonian = data['cost_hamiltonian']
cost_hamiltonian = Hamiltonian.classical_hamiltonian(knapsack_qubo.terms,cost_hamiltonian['coeffs'],cost_hamiltonian['constant'])

result = QAOAResult.from_dict(data,cost_hamiltonian)

# %%
result.plot_cost(figsize=(8,4))

# %%
result.plot_probabilities(figsize=(8,4))
# Out:
# states kept: 40

# %%
print(f"The solutions found with brute force are {configuration} with an energy of {energy}")
print()

most_probable_states = ''
#display( result.most_probable_states)
for i in result.most_probable_states['solutions_bitstrings']:
    most_probable_states += i + ','
most_probable_states = most_probable_states[:-1]
print('The most probable state/s are',most_probable_states,'with an energy of',result.most_probable_states['bitstring_energy'])
print()

lowest_cost_bitstrings = result.lowest_cost_bitstrings(2)
#display(lowest_cost_bitstrings)
for i in range(2):
    print('One of the lowest cost bitstring is',lowest_cost_bitstrings['solutions_bitstrings'][i],'with an energy of',
          lowest_cost_bitstrings['bitstrings_energies'][i],'and prob. of occurance of', lowest_cost_bitstrings['probabilities'][i])
    print()
# Out:
# The solutions found with brute force are ['00011010', '00001110'] with an energy of -7.0
#
# The most probable state/s are 11000001 with an energy of 6.0
#
# One of the lowest cost bitstring is 00011010 with an energy of -7.0 and prob. of occurance of 0.0002
#
# One of the lowest cost bitstring is 01000110 with an energy of -6.0 and prob. of occurance of 0.0058

# %% [markdown]
# ### Solution with highest cost:
# #### 3-standard_w_bias-ramp-x-Nelder_mead

# %%
import json
from openqaoa.algorithms import QAOAResult
from openqaoa.qaoa_components import Hamiltonian

with open('../../exp1/problem1/prob1_3-standard_w_bias-ramp-x-Nelder-Mead.json', 'r') as file:
    data = json.load(file)
cost_hamiltonian = data['cost_hamiltonian']
cost_hamiltonian = Hamiltonian.classical_hamiltonian(knapsack_qubo.terms,cost_hamiltonian['coeffs'],cost_hamiltonian['constant'])

result = QAOAResult.from_dict(data,cost_hamiltonian)

# %%
result.plot_cost(figsize=(8,4))

# %%
result.plot_probabilities(figsize=(8,4))
# Out:
# states kept: 40

# %%
print(f"The solutions found with brute force are {configuration} with an energy of {energy}")
print()

most_probable_states = ''
#display( result.most_probable_states)
for i in result.most_probable_states['solutions_bitstrings']:
    most_probable_states += i + ','
most_probable_states = most_probable_states[:-1]
print('The most probable state/s are',most_probable_states,'with an energy of',result.most_probable_states['bitstring_energy'])
print()

lowest_cost_bitstrings = result.lowest_cost_bitstrings(2)
#display(lowest_cost_bitstrings)
for i in range(2):
    print('One of the lowest cost bitstring is',lowest_cost_bitstrings['solutions_bitstrings'][i],'with an energy of',
          lowest_cost_bitstrings['bitstrings_energies'][i],'and prob. of occurance of', lowest_cost_bitstrings['probabilities'][i])
    print()
# Out:
# The solutions found with brute force are ['00011010', '00001110'] with an energy of -7.0
#
# The most probable state/s are 00110101 with an energy of 502.0
#
# One of the lowest cost bitstring is 00001110 with an energy of -7.0 and prob. of occurance of 0.0018
#
# One of the lowest cost bitstring is 00011010 with an energy of -7.0 and prob. of occurance of 0.003

# %% [markdown]
# ### Solution with lowest amount of iterations:
# #### 3-annealing-rand-xy-COBYLA

# %%
import json
from openqaoa.algorithms import QAOAResult
from openqaoa.qaoa_components import Hamiltonian

with open('../../exp1/problem1/prob1_3-annealing-rand-xy-COBYLA.json', 'r') as file:
    data = json.load(file)
cost_hamiltonian = data['cost_hamiltonian']
cost_hamiltonian = Hamiltonian.classical_hamiltonian(knapsack_qubo.terms,cost_hamiltonian['coeffs'],cost_hamiltonian['constant'])

result = QAOAResult.from_dict(data,cost_hamiltonian)

# %%
result.plot_cost(figsize=(8,4))

# %%
result.plot_probabilities(figsize=(8,4))
# Out:
# states kept: 40

# %%
print(f"The solutions found with brute force are {configuration} with an energy of {energy}")
print()

most_probable_states = ''
#display( result.most_probable_states)
for i in result.most_probable_states['solutions_bitstrings']:
    most_probable_states += i + ','
most_probable_states = most_probable_states[:-1]
print('The most probable state/s are',most_probable_states,'with an energy of',result.most_probable_states['bitstring_energy'])
print()

lowest_cost_bitstrings = result.lowest_cost_bitstrings(2)
#display(lowest_cost_bitstrings)
for i in range(2):
    print('One of the lowest cost bitstring is',lowest_cost_bitstrings['solutions_bitstrings'][i],'with an energy of',
          lowest_cost_bitstrings['bitstrings_energies'][i],'and prob. of occurance of', lowest_cost_bitstrings['probabilities'][i])
    print()
# Out:
# The solutions found with brute force are ['00011010', '00001110'] with an energy of -7.0
#
# The most probable state/s are 11001100 with an energy of 27.0
#
# One of the lowest cost bitstring is 00011010 with an energy of -7.0 and prob. of occurance of 0.0012
#
# One of the lowest cost bitstring is 00001110 with an energy of -7.0 and prob. of occurance of 0.0044

# %% [markdown]
# ### Solution with highest amount of iterations:
# #### 4-standard_w_bias-ramp-x-Powell

# %%
import json
from openqaoa.algorithms import QAOAResult
from openqaoa.qaoa_components import Hamiltonian

with open('../../exp1/problem1/prob1_4-standard_w_bias-ramp-x-Powell.json', 'r') as file:
    data = json.load(file)
cost_hamiltonian = data['cost_hamiltonian']
cost_hamiltonian = Hamiltonian.classical_hamiltonian(knapsack_qubo.terms,cost_hamiltonian['coeffs'],cost_hamiltonian['constant'])

result = QAOAResult.from_dict(data,cost_hamiltonian)

# %%
result.plot_cost(figsize=(8,4))

# %%
result.plot_probabilities(figsize=(8,4))
# Out:
# states kept: 40

# %%
print(f"The solutions found with brute force are {configuration} with an energy of {energy}")
print()

most_probable_states = ''
#display( result.most_probable_states)
for i in result.most_probable_states['solutions_bitstrings']:
    most_probable_states += i + ','
most_probable_states = most_probable_states[:-1]
print('The most probable state/s are',most_probable_states,'with an energy of',result.most_probable_states['bitstring_energy'])
print()

lowest_cost_bitstrings = result.lowest_cost_bitstrings(2)
#display(lowest_cost_bitstrings)
for i in range(2):
    print('One of the lowest cost bitstring is',lowest_cost_bitstrings['solutions_bitstrings'][i],'with an energy of',
          lowest_cost_bitstrings['bitstrings_energies'][i],'and prob. of occurance of', lowest_cost_bitstrings['probabilities'][i])
    print()
# Out:
# The solutions found with brute force are ['00011010', '00001110'] with an energy of -7.0
#
# The most probable state/s are 10100001 with an energy of 6.0
#
# One of the lowest cost bitstring is 00010001 with an energy of -6.0 and prob. of occurance of 0.0006
#
# One of the lowest cost bitstring is 10001011 with an energy of -5.0 and prob. of occurance of 0.0002
