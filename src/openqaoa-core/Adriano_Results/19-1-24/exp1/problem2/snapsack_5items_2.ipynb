# %%
import networkx as nx
from openqaoa.problems import Knapsack

knapsack_prob = Knapsack(values=[2, 3, 4, 1, 1],weights=[1, 1, 4, 3, 2],weight_capacity=9,penalty=8)
print(knapsack_prob.problem_instance)
knapsack_qubo = knapsack_prob.qubo
knapsack_hamiltonian = knapsack_qubo.hamiltonian
# Out:
# {'problem_type': 'knapsack', 'values': [2, 3, 4, 1, 1], 'weights': [1, 1, 4, 3, 2], 'weight_capacity': 9, 'penalty': 8, 'n_items': 5}

# %%
{'problem_type': 'knapsack', 'values': [2, 3, 4, 1, 1], 'weights': [1, 1, 4, 3, 2], 'weight_capacity': 9, 'penalty': 8, 'n_items': 5}

# %%
from qiskit_ibm_provider import IBMProvider
IBMProvider.save_account('825a8b2e6fb861f63088f866e59357e49447b4b9b24ff6136e56dcc28f2fb0cedda6c2976b9e2aef48129a80864265494be7f8a7aae5b9ebd6654a7d80d9b5cb')

# %%
from tqdm import tqdm
from openqaoa.backends import create_device
from openqaoa import QAOA
from openqaoa.utilities import ground_state_hamiltonian
import matplotlib.pyplot as plt
import json


itr = 0
yahice = range(1,62)
ps = [3, 4, 5, 6]
param_types = ["standard", "standard_w_bias", "annealing"]
init_types = ["rand", "ramp"]
mixer_hams = ["x", "xy"]
optimizers = ["Nelder-Mead", "Powell", "COBYLA"]
for p in tqdm(ps):
    for param_type in tqdm(param_types):
        for init_type in tqdm(init_types):
            for mixer_hamiltonian in tqdm(mixer_hams):
                for optimizer in tqdm(optimizers):
                    print("params = prob2_%s-%s-%s-%s-%s" % (str(p), str(param_type), str(init_type), str(mixer_hamiltonian), str(optimizer)))
                    itr = itr+1
                    print('itr ',itr)
                    if itr in yahice:
                        continue
                    
                    q1 = QAOA()
                    #qiskit_device = create_device(location='local', name='qiskit.shot_simulator')
                    qiskit_device = create_device(location='ibmq', name='ibmq_qasm_simulator')
                    q1.set_device(qiskit_device)
                    q1.set_circuit_properties(p=p, param_type=param_type, init_type=init_type, mixer_hamiltonian=mixer_hamiltonian)
                    q1.set_backend_properties(n_shots=5000, seed_simulator=1)
                    q1.set_classical_optimizer(method=optimizer, maxiter=200, tol=0.01,
                    optimization_progress=True, cost_progress=True, parameter_log=True)
                    q1.compile(knapsack_qubo)
                    q1.optimize()
                    correct_solution1 = ground_state_hamiltonian(q1.cost_hamil)
                    print(correct_solution1)
                    opt_results1 = q1.result

                    with open('prob2_%s-%s-%s-%s-%s.json'% (str(p), str(param_type), str(init_type), str(mixer_hamiltonian), str(optimizer)), 'w') as archivo:
                        json.dump(opt_results1.asdict(), archivo)

                    
                    fig, ax = plt.subplots(figsize=(7,4))
                    opt_results1.plot_cost(figsize=(7,4),color='blue',label='qaoa',ax=ax)
                    plt.savefig("prob2_%s-%s-%s-%s-%s.png" % (str(p), str(param_type), str(init_type), str(mixer_hamiltonian), str(optimizer)))
# Out:
#   0%|                                                                                            | 0/4 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
#
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#
#
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<?, ?it/s]
# params = prob2_3-standard-rand-x-Nelder-Mead
# itr  1
# params = prob2_3-standard-rand-x-Powell
# itr  2
# params = prob2_3-standard-rand-x-COBYLA
# itr  3
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
# params = prob2_3-standard-rand-xy-Nelder-Mead
# itr  4
# (-10.0, ['000011110', '100011101'])
#  33%|██████████████████████████▋                                                     | 1/3 [44:37<1:29:15, 2677.87s/it]
# params = prob2_3-standard-rand-xy-Powell
# itr  5
# (-10.0, ['000011110', '100011101'])
#  67%|██████████████████████████████████████████████████████▋                           | 2/3 [59:03<26:51, 1611.73s/it]
# params = prob2_3-standard-rand-xy-COBYLA
# itr  6
# 100%|████████████████████████████████████████████████████████████████████████████████| 3/3 [1:02:16<00:00, 1245.64s/it]
#
#
#
# 100%|████████████████████████████████████████████████████████████████████████████████| 2/2 [1:02:16<00:00, 1868.48s/it]
# (-10.0, ['000011110', '100011101'])
#  50%|███████████████████████████████████████                                       | 1/2 [1:02:16<1:02:16, 3736.96s/it]
#
#
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#
#
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
# params = prob2_3-standard-ramp-x-Nelder-Mead
# itr  7
# (-10.0, ['000011110', '100011101'])
#  33%|██████████████████████████▋                                                     | 1/3 [36:03<1:12:06, 2163.13s/it]
# params = prob2_3-standard-ramp-x-Powell
# itr  8
# (-10.0, ['000011110', '100011101'])
#  67%|██████████████████████████████████████████████████████▋                           | 2/3 [52:15<24:22, 1462.61s/it]
# params = prob2_3-standard-ramp-x-COBYLA
# itr  9
# (-10.0, ['000011110', '100011101'])
# 100%|██████████████████████████████████████████████████████████████████████████████████| 3/3 [55:17<00:00, 1105.88s/it]
#
#
#
#  50%|█████████████████████████████████████████                                         | 1/2 [55:17<55:17, 3317.64s/it]
#
#
#
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
# params = prob2_3-standard-ramp-xy-Nelder-Mead
# itr  10
# (-10.0, ['000011110', '100011101'])
#  33%|██████████████████████████▋                                                     | 1/3 [47:05<1:34:11, 2825.69s/it]
# params = prob2_3-standard-ramp-xy-Powell
# itr  11
# (-10.0, ['000011110', '100011101'])
#  67%|████████████████████████████████████████████████████                          | 2/3 [2:07:25<1:06:38, 3998.53s/it]
# params = prob2_3-standard-ramp-xy-COBYLA
# itr  12
# 100%|████████████████████████████████████████████████████████████████████████████████| 3/3 [2:11:48<00:00, 2636.26s/it]
# (-10.0, ['000011110', '100011101'])
# 100%|████████████████████████████████████████████████████████████████████████████████| 2/2 [3:07:06<00:00, 5613.21s/it]
#
#
# 100%|████████████████████████████████████████████████████████████████████████████████| 2/2 [4:09:23<00:00, 7481.70s/it]
#
#  33%|█████████████████████████▋                                                   | 1/3 [4:09:23<8:18:46, 14963.40s/it]
#
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#
#
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
# params = prob2_3-standard_w_bias-rand-x-Nelder-Mead
# itr  13
# (-10.0, ['000011110', '100011101'])
#  33%|██████████████████████████▋                                                     | 1/3 [41:00<1:22:01, 2460.86s/it]
# params = prob2_3-standard_w_bias-rand-x-Powell
# itr  14
# (-10.0, ['000011110', '100011101'])
#  67%|█████████████████████████████████████████████████████▎                          | 2/3 [1:20:36<40:10, 2410.73s/it]
# params = prob2_3-standard_w_bias-rand-x-COBYLA
# itr  15
# (-10.0, ['000011110', '100011101'])
# 100%|████████████████████████████████████████████████████████████████████████████████| 3/3 [1:23:01<00:00, 1660.60s/it]
#
#
#
#  50%|███████████████████████████████████████                                       | 1/2 [1:23:01<1:23:01, 4981.81s/it]
#
#
#
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
# params = prob2_3-standard_w_bias-rand-xy-Nelder-Mead
# itr  16
# (-10.0, ['000011110', '100011101'])
#  33%|██████████████████████████▋                                                     | 1/3 [52:58<1:45:55, 3178.00s/it]
# params = prob2_3-standard_w_bias-rand-xy-Powell
# itr  17
# (-10.0, ['000011110', '100011101'])
#  67%|█████████████████████████████████████████████████████▎                          | 2/3 [1:36:37<47:29, 2849.61s/it]
# params = prob2_3-standard_w_bias-rand-xy-COBYLA
# itr  18
# (-10.0, ['000011110', '100011101'])
# 100%|████████████████████████████████████████████████████████████████████████████████| 3/3 [1:40:37<00:00, 2012.56s/it]
#
#
#
# 100%|████████████████████████████████████████████████████████████████████████████████| 2/2 [3:03:39<00:00, 5509.76s/it]
#
#
#  50%|██████████████████████████████████████▌                                      | 1/2 [3:03:39<3:03:39, 11019.52s/it]
#
#
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#
#
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
# params = prob2_3-standard_w_bias-ramp-x-Nelder-Mead
# itr  19
# (-10.0, ['000011110', '100011101'])
#  33%|██████████████████████████▋                                                     | 1/3 [37:05<1:14:11, 2225.94s/it]
# params = prob2_3-standard_w_bias-ramp-x-Powell
# itr  20
# (-10.0, ['000011110', '100011101'])
#  67%|█████████████████████████████████████████████████████▎                          | 2/3 [1:07:30<33:09, 1989.84s/it]
# params = prob2_3-standard_w_bias-ramp-x-COBYLA
# itr  21
# 100%|████████████████████████████████████████████████████████████████████████████████| 3/3 [1:10:54<00:00, 1418.07s/it]
#
#
#
#  50%|███████████████████████████████████████                                       | 1/2 [1:10:54<1:10:54, 4254.23s/it]
# (-10.0, ['000011110', '100011101'])
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
# params = prob2_3-standard_w_bias-ramp-xy-Nelder-Mead
# itr  22
# (-10.0, ['000011110', '100011101'])
#  33%|██████████████████████████▋                                                     | 1/3 [58:54<1:57:48, 3534.40s/it]
# params = prob2_3-standard_w_bias-ramp-xy-Powell
# itr  23
# (-10.0, ['000011110', '100011101'])
#  67%|████████████████████████████████████████████████████                          | 2/3 [2:03:12<1:02:04, 3724.83s/it]
# params = prob2_3-standard_w_bias-ramp-xy-COBYLA
# itr  24
# C:\Users\Adriano\AppData\Local\Temp\ipykernel_2692\45459616.py:45: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, ax = plt.subplots(figsize=(7,4))
# (-10.0, ['000011110', '100011101'])
# 100%|████████████████████████████████████████████████████████████████████████████████| 3/3 [2:08:12<00:00, 2564.19s/it]
#
#
#
# 100%|████████████████████████████████████████████████████████████████████████████████| 2/2 [3:19:06<00:00, 5973.40s/it]
#
#
# 100%|███████████████████████████████████████████████████████████████████████████████| 2/2 [6:22:46<00:00, 11483.17s/it]
#
#  67%|██████████████████████████████████████████████████▋                         | 2/3 [10:32:09<5:27:51, 19671.01s/it]
#
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#
#
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
# params = prob2_3-annealing-rand-x-Nelder-Mead
# itr  25
# (-10.0, ['000011110', '100011101'])
#  33%|██████████████████████████▋                                                     | 1/3 [32:33<1:05:06, 1953.44s/it]
# params = prob2_3-annealing-rand-x-Powell
# itr  26
# (-10.0, ['000011110', '100011101'])
#  67%|██████████████████████████████████████████████████████▋                           | 2/3 [42:14<19:06, 1146.33s/it]
# params = prob2_3-annealing-rand-x-COBYLA
# itr  27
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [43:44<00:00, 874.98s/it]
#
#
#
#  50%|█████████████████████████████████████████                                         | 1/2 [43:44<43:44, 2624.96s/it]
# (-10.0, ['000011110', '100011101'])
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
# params = prob2_3-annealing-rand-xy-Nelder-Mead
# itr  28
# (-10.0, ['000011110', '100011101'])
#  33%|██████████████████████████▋                                                     | 1/3 [45:06<1:30:13, 2706.73s/it]
# params = prob2_3-annealing-rand-xy-Powell
# itr  29
# (-10.0, ['000011110', '100011101'])
#  67%|██████████████████████████████████████████████████████▋                           | 2/3 [59:41<27:08, 1628.96s/it]
# params = prob2_3-annealing-rand-xy-COBYLA
# itr  30
# 100%|████████████████████████████████████████████████████████████████████████████████| 3/3 [1:01:39<00:00, 1233.03s/it]
# (-10.0, ['000011110', '100011101'])
# 100%|████████████████████████████████████████████████████████████████████████████████| 2/2 [1:45:24<00:00, 3162.03s/it]
#
#
#  50%|███████████████████████████████████████                                       | 1/2 [1:45:24<1:45:24, 6324.07s/it]
#
#
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#
#
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
# params = prob2_3-annealing-ramp-x-Nelder-Mead
# itr  31
# (-10.0, ['000011110', '100011101'])
#  33%|██████████████████████████▋                                                     | 1/3 [30:08<1:00:16, 1808.33s/it]
# params = prob2_3-annealing-ramp-x-Powell
# itr  32
# (-10.0, ['000011110', '100011101'])
#  67%|███████████████████████████████████████████████████████▎                           | 2/3 [34:02<14:42, 882.57s/it]
# params = prob2_3-annealing-ramp-x-COBYLA
# itr  33
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [35:29<00:00, 709.79s/it]
#
#
#
#  50%|█████████████████████████████████████████                                         | 1/2 [35:29<35:29, 2129.37s/it]
# (-10.0, ['000011110', '100011101'])
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
# params = prob2_3-annealing-ramp-xy-Nelder-Mead
# itr  34
# (-10.0, ['000011110', '100011101'])
#  33%|██████████████████████████▋                                                     | 1/3 [41:27<1:22:54, 2487.34s/it]
# params = prob2_3-annealing-ramp-xy-Powell
# itr  35
# (-10.0, ['000011110', '100011101'])
#  67%|██████████████████████████████████████████████████████▋                           | 2/3 [46:52<20:15, 1215.45s/it]
# params = prob2_3-annealing-ramp-xy-COBYLA
# itr  36
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [48:33<00:00, 971.17s/it]
#
#
#
# 100%|████████████████████████████████████████████████████████████████████████████████| 2/2 [1:24:02<00:00, 2521.45s/it]
#
#
# 100%|████████████████████████████████████████████████████████████████████████████████| 2/2 [3:09:26<00:00, 5683.49s/it]
#
# 100%|██████████████████████████████████████████████████████████████████████████████| 3/3 [13:41:36<00:00, 16432.24s/it]
#  25%|██████████████████▊                                                        | 1/4 [13:41:36<41:04:50, 49296.73s/it]
# (-10.0, ['000011110', '100011101'])
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
#
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#
#
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
# params = prob2_4-standard-rand-x-Nelder-Mead
# itr  37
# (-10.0, ['000011110', '100011101'])
#  33%|██████████████████████████▋                                                     | 1/3 [37:06<1:14:13, 2226.55s/it]
# params = prob2_4-standard-rand-x-Powell
# itr  38
# (-10.0, ['000011110', '100011101'])
#  67%|█████████████████████████████████████████████████████▎                          | 2/3 [1:18:19<39:31, 2371.70s/it]
# params = prob2_4-standard-rand-x-COBYLA
# itr  39
# 100%|████████████████████████████████████████████████████████████████████████████████| 3/3 [1:21:22<00:00, 1627.41s/it]
#
#
#
#  50%|███████████████████████████████████████                                       | 1/2 [1:21:22<1:21:22, 4882.22s/it]
# (-10.0, ['000011110', '100011101'])
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
# params = prob2_4-standard-rand-xy-Nelder-Mead
# itr  40
# (-10.0, ['000011110', '100011101'])
#  33%|██████████████████████████▋                                                     | 1/3 [49:19<1:38:38, 2959.13s/it]
# params = prob2_4-standard-rand-xy-Powell
# itr  41
# (-10.0, ['000011110', '100011101'])
#  67%|█████████████████████████████████████████████████████▎                          | 2/3 [1:17:29<36:53, 2213.06s/it]
# params = prob2_4-standard-rand-xy-COBYLA
# itr  42
# 100%|████████████████████████████████████████████████████████████████████████████████| 3/3 [1:21:33<00:00, 1631.02s/it]
#
#
#
# 100%|████████████████████████████████████████████████████████████████████████████████| 2/2 [2:42:55<00:00, 4887.66s/it]
#
#
#  50%|███████████████████████████████████████                                       | 1/2 [2:42:55<2:42:55, 9775.32s/it]
# (-10.0, ['000011110', '100011101'])
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#
#
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
# params = prob2_4-standard-ramp-x-Nelder-Mead
# itr  43
# (-10.0, ['000011110', '100011101'])
#  33%|██████████████████████████▋                                                     | 1/3 [35:55<1:11:50, 2155.34s/it]
# params = prob2_4-standard-ramp-x-Powell
# itr  44
# (-10.0, ['000011110', '100011101'])
#  67%|█████████████████████████████████████████████████████▎                          | 2/3 [1:39:19<52:05, 3125.44s/it]
# params = prob2_4-standard-ramp-x-COBYLA
# itr  45
# (-10.0, ['000011110', '100011101'])
# 100%|████████████████████████████████████████████████████████████████████████████████| 3/3 [1:42:52<00:00, 2057.49s/it]
#
#
#
#  50%|███████████████████████████████████████                                       | 1/2 [1:42:52<1:42:52, 6172.46s/it]
#
#
#
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
# params = prob2_4-standard-ramp-xy-Nelder-Mead
# itr  46
# (-10.0, ['000011110', '100011101'])
#  33%|██████████████████████████▋                                                     | 1/3 [49:06<1:38:13, 2946.77s/it]
# params = prob2_4-standard-ramp-xy-Powell
# itr  47
# (-10.0, ['000011110', '100011101'])
#  67%|█████████████████████████████████████████████████████▎                          | 2/3 [1:00:29<26:54, 1614.95s/it]
# params = prob2_4-standard-ramp-xy-COBYLA
# itr  48
# 100%|████████████████████████████████████████████████████████████████████████████████| 3/3 [1:04:16<00:00, 1285.39s/it]
#
#
#
# 100%|████████████████████████████████████████████████████████████████████████████████| 2/2 [2:47:08<00:00, 5014.33s/it]
#
#
# 100%|████████████████████████████████████████████████████████████████████████████████| 2/2 [5:30:03<00:00, 9901.99s/it]
#
#  33%|█████████████████████████▎                                                  | 1/3 [5:30:03<11:00:07, 19803.99s/it]
# (-10.0, ['000011110', '100011101'])
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#
#
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
# params = prob2_4-standard_w_bias-rand-x-Nelder-Mead
# itr  49
# (-10.0, ['000011110', '100011101'])
#  33%|██████████████████████████▋                                                     | 1/3 [38:36<1:17:12, 2316.19s/it]
# params = prob2_4-standard_w_bias-rand-x-Powell
# itr  50
# (-10.0, ['000011110', '100011101'])
#  67%|█████████████████████████████████████████████████████▎                          | 2/3 [1:30:08<46:12, 2772.74s/it]
# params = prob2_4-standard_w_bias-rand-x-COBYLA
# itr  51
# 100%|████████████████████████████████████████████████████████████████████████████████| 3/3 [1:34:10<00:00, 1616.99s/it]
# (-10.0, ['000011110', '100011101'])
# 100%|████████████████████████████████████████████████████████████████████████████████| 3/3 [1:34:10<00:00, 1883.39s/it]
#
#
#
#  50%|███████████████████████████████████████                                       | 1/2 [1:34:10<1:34:10, 5650.17s/it]
#
#
#
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
# params = prob2_4-standard_w_bias-rand-xy-Nelder-Mead
# itr  52
# (-10.0, ['000011110', '100011101'])
#  33%|██████████████████████████▋                                                     | 1/3 [53:16<1:46:33, 3196.70s/it]
# params = prob2_4-standard_w_bias-rand-xy-Powell
# itr  53
# (-10.0, ['000011110', '100011101'])
#  67%|█████████████████████████████████████████████████████▎                          | 2/3 [1:52:50<56:58, 3418.56s/it]
# params = prob2_4-standard_w_bias-rand-xy-COBYLA
# itr  54
# (-10.0, ['000011110', '100011101'])
# 100%|████████████████████████████████████████████████████████████████████████████████| 3/3 [1:58:46<00:00, 2375.50s/it]
#
#
#
# 100%|████████████████████████████████████████████████████████████████████████████████| 2/2 [3:32:56<00:00, 6388.34s/it]
#
#
#  50%|██████████████████████████████████████▌                                      | 1/2 [3:32:56<3:32:56, 12776.69s/it]
#
#
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#
#
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
# params = prob2_4-standard_w_bias-ramp-x-Nelder-Mead
# itr  55
# (-10.0, ['000011110', '100011101'])
#  33%|██████████████████████████▋                                                     | 1/3 [38:31<1:17:03, 2311.77s/it]
# params = prob2_4-standard_w_bias-ramp-x-Powell
# itr  56
# (-10.0, ['000011110', '100011101'])
#  67%|█████████████████████████████████████████████████████▎                          | 2/3 [1:25:10<43:18, 2598.51s/it]
# params = prob2_4-standard_w_bias-ramp-x-COBYLA
# itr  57
# (-10.0, ['000011110', '100011101'])
# 100%|████████████████████████████████████████████████████████████████████████████████| 3/3 [1:29:33<00:00, 1791.30s/it]
#
#
#
#  50%|███████████████████████████████████████                                       | 1/2 [1:29:33<1:29:33, 5373.90s/it]
#
#
#
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
# params = prob2_4-standard_w_bias-ramp-xy-Nelder-Mead
# itr  58
# (-10.0, ['000011110', '100011101'])
#  33%|██████████████████████████▋                                                     | 1/3 [44:25<1:28:50, 2665.29s/it]
# params = prob2_4-standard_w_bias-ramp-xy-Powell
# itr  59
# (-10.0, ['000011110', '100011101'])
#  67%|█████████████████████████████████████████████████████▎                          | 2/3 [1:23:28<41:16, 2476.06s/it]
# params = prob2_4-standard_w_bias-ramp-xy-COBYLA
# itr  60
# (-10.0, ['000011110', '100011101'])
# 100%|████████████████████████████████████████████████████████████████████████████████| 3/3 [1:28:53<00:00, 1777.72s/it]
#
#
#
# 100%|████████████████████████████████████████████████████████████████████████████████| 2/2 [2:58:27<00:00, 5353.54s/it]
#
#
# 100%|███████████████████████████████████████████████████████████████████████████████| 2/2 [6:31:23<00:00, 11741.89s/it]
#
#  67%|██████████████████████████████████████████████████▋                         | 2/3 [12:01:27<6:06:08, 21968.56s/it]
#
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#
#
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
# params = prob2_4-annealing-rand-x-Nelder-Mead
# itr  61
# (-10.0, ['000011110', '100011101'])
#  33%|██████████████████████████▋                                                     | 1/3 [32:22<1:04:44, 1942.47s/it]
# params = prob2_4-annealing-rand-x-Powell
# itr  62
#  33%|██████████████████████████▋                                                     | 1/3 [38:57<1:17:54, 2337.47s/it]
#   0%|                                                                                            | 0/2 [38:57<?, ?it/s]
#   0%|                                                                                            | 0/2 [38:57<?, ?it/s]
#  67%|██████████████████████████████████████████████████▋                         | 2/3 [12:40:25<6:20:12, 22812.63s/it]
#  25%|██████████████████▊                                                        | 1/4 [26:22:02<79:06:06, 94922.01s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 36
#      33 q1.set_classical_optimizer(method=optimizer, maxiter=200, tol=0.01,
#      34 optimization_progress=True, cost_progress=True, parameter_log=True)
#      35 q1.compile(knapsack_qubo)
# ---> 36 q1.optimize()
#      37 correct_solution1 = ground_state_hamiltonian(q1.cost_hamil)
#      38 print(correct_solution1)
#
# File ~\anaconda3\envs\quantum\lib\site-packages\openqaoa\algorithms\qaoa\qaoa_workflow.py:371, in QAOA.optimize(self, verbose)
#     368 # timestamp for the start of the optimization
#     369 self.header["execution_time_start"] = generate_timestamp()
# --> 371 self.optimizer.optimize()
#     372 # TODO: result and qaoa_result will differ
#     373 self.result = self.optimizer.qaoa_result
#
# File ~\anaconda3\envs\quantum\lib\site-packages\openqaoa\optimizers\training_vqa.py:499, in ScipyOptimizer.optimize(self)
#     487             result = minimize(
#     488                 self.optimize_this,
#     489                 x0=self.initial_params,
#    (...)
#     496                 bounds=self.bounds,
#     497             )
#     498     else:
# --> 499         result = minimize(
#     500             self.optimize_this,
#     501             x0=self.initial_params,
#     502             method=self.method,
#     503             tol=self.tol,
#     504             constraints=self.constraints,
#     505             options=self.options,
#     506             bounds=self.bounds,
#     507         )
#     508 except ConnectionError as e:
#     509     print(e, "\n")
#
# File ~\anaconda3\envs\quantum\lib\site-packages\scipy\optimize\_minimize.py:687, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     684     res = _minimize_neldermead(fun, x0, args, callback, bounds=bounds,
#     685                                **options)
#     686 elif meth == 'powell':
# --> 687     res = _minimize_powell(fun, x0, args, callback, bounds, **options)
#     688 elif meth == 'cg':
#     689     res = _minimize_cg(fun, x0, args, jac, callback, **options)
#
# File ~\anaconda3\envs\quantum\lib\site-packages\scipy\optimize\_optimize.py:3346, in _minimize_powell(func, x0, args, callback, bounds, xtol, ftol, maxiter, maxfev, disp, direc, return_all, **unknown_options)
#    3344 direc1 = direc[i]
#    3345 fx2 = fval
# -> 3346 fval, x, direc1 = _linesearch_powell(func, x, direc1,
#    3347                                      tol=xtol * 100,
#    3348                                      lower_bound=lower_bound,
#    3349                                      upper_bound=upper_bound,
#    3350                                      fval=fval)
#    3351 if (fx2 - fval) > delta:
#    3352     delta = fx2 - fval
#
# File ~\anaconda3\envs\quantum\lib\site-packages\scipy\optimize\_optimize.py:3025, in _linesearch_powell(func, p, xi, tol, lower_bound, upper_bound, fval)
#    3022     return ((fval, p, xi) if fval is not None else (func(p), p, xi))
#    3023 elif lower_bound is None and upper_bound is None:
#    3024     # non-bounded minimization
# -> 3025     alpha_min, fret, _, _ = brent(myfunc, full_output=1, tol=tol)
#    3026     xi = alpha_min * xi
#    3027     return squeeze(fret), p + xi, xi
#
# File ~\anaconda3\envs\quantum\lib\site-packages\scipy\optimize\_optimize.py:2569, in brent(func, args, brack, tol, full_output, maxiter)
#    2498 """
#    2499 Given a function of one variable and a possible bracket, return
#    2500 the local minimum of the function isolated to a fractional precision
#    (...)
#    2565
#    2566 """
#    2567 options = {'xtol': tol,
#    2568            'maxiter': maxiter}
# -> 2569 res = _minimize_scalar_brent(func, brack, args, **options)
#    2570 if full_output:
#    2571     return res['x'], res['fun'], res['nit'], res['nfev']
#
# File ~\anaconda3\envs\quantum\lib\site-packages\scipy\optimize\_optimize.py:2606, in _minimize_scalar_brent(func, brack, args, xtol, maxiter, disp, **unknown_options)
#    2603 brent = Brent(func=func, args=args, tol=tol,
#    2604               full_output=True, maxiter=maxiter, disp=disp)
#    2605 brent.set_bracket(brack)
# -> 2606 brent.optimize()
#    2607 x, fval, nit, nfev = brent.get_result(full_output=True)
#    2609 success = nit < maxiter and not (np.isnan(x) or np.isnan(fval))
#
# File ~\anaconda3\envs\quantum\lib\site-packages\scipy\optimize\_optimize.py:2449, in Brent.optimize(self)
#    2447 else:
#    2448     u = x + rat
# -> 2449 fu = func(*((u,) + self.args))      # calculate new output value
#    2450 funcalls += 1
#    2452 if (fu > fx):                 # if it's bigger than current
#
# File ~\anaconda3\envs\quantum\lib\site-packages\scipy\optimize\_optimize.py:3018, in _linesearch_powell.<locals>.myfunc(alpha)
#    3017 def myfunc(alpha):
# -> 3018     return func(p + alpha*xi)
#
# File ~\anaconda3\envs\quantum\lib\site-packages\scipy\optimize\_optimize.py:569, in _wrap_scalar_function_maxfun_validation.<locals>.function_wrapper(x, *wrapper_args)
#     567 ncalls[0] += 1
#     568 # A copy of x is sent to the user function (gh13740)
# --> 569 fx = function(np.copy(x), *(wrapper_args + args))
#     570 # Ideally, we'd like to a have a true scalar returned from f(x). For
#     571 # backwards-compatibility, also allow np.array([1.3]),
#     572 # np.array([[1.3]]) etc.
#     573 if not np.isscalar(fx):
#
# File ~\anaconda3\envs\quantum\lib\site-packages\openqaoa\optimizers\training_vqa.py:232, in OptimizeVQA.optimize_this(self, x, n_shots)
#     229     save_parameter("param_log", deepcopy(x))
#     231 n_shots_dict = {"n_shots": n_shots} if n_shots else {}
# --> 232 callback_cost = self.vqa.expectation(self.variational_params, **n_shots_dict)
#     234 log_dict.update({"cost": callback_cost})
#     236 current_eval = self.log.func_evals.best[0]
#
# File ~\anaconda3\envs\quantum\lib\site-packages\openqaoa\utilities.py:252, in round_value.<locals>.wrapper(*args, **kwargs)
#     251 def wrapper(*args, **kwargs):
# --> 252     values = function(*args, **kwargs)
#     253     if isinstance(values, dict):
#     254         return {k: round(v, PRECISION) for k, v in values.items()}
#
# File ~\anaconda3\envs\quantum\lib\site-packages\openqaoa\backends\basebackend.py:282, in QAOABaseBackend.expectation(self, params, n_shots)
#     264 @round_value
#     265 def expectation(self, params: QAOAVariationalBaseParams, n_shots=None) -> float:
#     266     """
#     267     Compute the expectation value w.r.t the Cost Hamiltonian
#     268
#    (...)
#     280         Expectation value of cost operator wrt to quantum state produced by QAOA circuit
#     281     """
# --> 282     counts = self.get_counts(params, n_shots)
#     283     cost = cost_function(
#     284         counts, self.qaoa_descriptor.cost_hamiltonian, self.cvar_alpha
#     285     )
#     286     return cost
#
# File ~\anaconda3\envs\quantum\lib\site-packages\openqaoa_qiskit\backends\qaoa_qiskit_qpu.py:244, in QAOAQiskitQPUBackend.get_counts(self, params, n_shots)
#     238 max_job_retries = 5
#     240 while job_state is False:
#     241     # initial_layout only passed if not azure device
#     242     # if type(self.device).__name__ == "DeviceAzure":
#     243     # job = self.backend_qpu.run(circuit, **input_items)
# --> 244     job = self.device.backend_device.run(circuit, shots=n_shots)
#     246     api_contact = False
#     247     no_of_api_retries = 0
#
# File ~\anaconda3\envs\quantum\lib\site-packages\qiskit_ibm_provider\ibm_backend.py:445, in IBMBackend.run(self, circuits, dynamic, job_tags, init_circuit, init_num_resets, header, shots, memory, meas_level, meas_return, rep_delay, init_qubits, use_measure_esp, noise_model, seed_simulator, **run_config)
#     440 if dynamic and "qasm3" not in getattr(
#     441     self.configuration(), "supported_features", []
#     442 ):
#     443     warnings.warn(f"The backend {self.name} does not support dynamic circuits.")
# --> 445 status = self.status()
#     446 if status.operational is True and status.status_msg != "active":
#     447     warnings.warn(f"The backend {self.name} is currently paused.")
#
# File ~\anaconda3\envs\quantum\lib\site-packages\qiskit_ibm_provider\ibm_backend.py:653, in IBMBackend.status(self)
#     639 def status(self) -> BackendStatus:
#     640     """Return the backend status.
#     641
#     642     Note:
#    (...)
#     651         IBMBackendApiProtocolError: If the status for the backend cannot be formatted properly.
#     652     """
# --> 653     api_status = self.provider._runtime_client.backend_status(self.name)
#     655     try:
#     656         return BackendStatus.from_dict(api_status)
#
# File ~\anaconda3\envs\quantum\lib\site-packages\qiskit_ibm_provider\api\clients\runtime.py:90, in RuntimeClient.backend_status(self, backend)
#      81 def backend_status(self, backend: str) -> Dict[str, Any]:
#      82     """Return the status of the backend.
#      83
#      84     Args:
#    (...)
#      88         Backend status.
#      89     """
# ---> 90     return self._api.backend(backend).status()
#
# File ~\anaconda3\envs\quantum\lib\site-packages\qiskit_ibm_provider\api\rest\backend.py:97, in Backend.status(self)
#      91 """Return backend status.
#      92
#      93 Returns:
#      94     JSON response of backend status.
#      95 """
#      96 url = self.get_url("status")
# ---> 97 response = self.session.get(url).json()
#      99 # Adjust fields according to the specs (BackendStatus).
#     100 ret = {
#     101     "backend_name": self.backend_name,
#     102     "backend_version": response.get("backend_version", "0.0.0"),
#     103     "status_msg": response.get("status", ""),
#     104     "operational": bool(response.get("state", False)),
#     105 }
#
# File ~\anaconda3\envs\quantum\lib\site-packages\requests\sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File ~\anaconda3\envs\quantum\lib\site-packages\qiskit_ibm_provider\api\session.py:263, in RetrySession.request(self, method, url, bare, **kwargs)
#     261 try:
#     262     self._log_request_info(final_url, method, kwargs)
# --> 263     response = super().request(method, final_url, headers=headers, **kwargs)
#     264     response.raise_for_status()
#     265 except RequestException as ex:
#     266     # Wrap the requests exceptions into a IBM Q custom one, for
#     267     # compatibility.
#
# File ~\anaconda3\envs\quantum\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\anaconda3\envs\quantum\lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\anaconda3\envs\quantum\lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~\anaconda3\envs\quantum\lib\site-packages\urllib3\connectionpool.py:715, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     712     self._prepare_proxy(conn)
#     714 # Make the request on the httplib connection object.
# --> 715 httplib_response = self._make_request(
#     716     conn,
#     717     method,
#     718     url,
#     719     timeout=timeout_obj,
#     720     body=body,
#     721     headers=headers,
#     722     chunked=chunked,
#     723 )
#     725 # If we're going to release the connection in ``finally:``, then
#     726 # the response doesn't need to know about the connection. Otherwise
#     727 # it will also try to release it and we'll have a double-release
#     728 # mess.
#     729 response_conn = conn if not release_conn else None
#
# File ~\anaconda3\envs\quantum\lib\site-packages\urllib3\connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     462             httplib_response = conn.getresponse()
#     463         except BaseException as e:
#     464             # Remove the TypeError from the exception chain in
#     465             # Python 3 (including for exceptions like SystemExit).
#     466             # Otherwise it looks like a bug in the code.
# --> 467             six.raise_from(e, None)
#     468 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     469     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~\anaconda3\envs\quantum\lib\site-packages\urllib3\connectionpool.py:462, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     459 except TypeError:
#     460     # Python 3
#     461     try:
# --> 462         httplib_response = conn.getresponse()
#     463     except BaseException as e:
#     464         # Remove the TypeError from the exception chain in
#     465         # Python 3 (including for exceptions like SystemExit).
#     466         # Otherwise it looks like a bug in the code.
#     467         six.raise_from(e, None)
#
# File ~\anaconda3\envs\quantum\lib\http\client.py:1348, in HTTPConnection.getresponse(self)
#    1346 try:
#    1347     try:
# -> 1348         response.begin()
#    1349     except ConnectionError:
#    1350         self.close()
#
# File ~\anaconda3\envs\quantum\lib\http\client.py:316, in HTTPResponse.begin(self)
#     314 # read until we get a non-100 response
#     315 while True:
# --> 316     version, status, reason = self._read_status()
#     317     if status != CONTINUE:
#     318         break
#
# File ~\anaconda3\envs\quantum\lib\http\client.py:277, in HTTPResponse._read_status(self)
#     276 def _read_status(self):
# --> 277     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     278     if len(line) > _MAXLINE:
#     279         raise LineTooLong("status line")
#
# File ~\anaconda3\envs\quantum\lib\socket.py:669, in SocketIO.readinto(self, b)
#     667 while True:
#     668     try:
# --> 669         return self._sock.recv_into(b)
#     670     except timeout:
#     671         self._timeout_occurred = True
#
# File ~\anaconda3\envs\quantum\lib\ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File ~\anaconda3\envs\quantum\lib\ssl.py:1132, in SSLSocket.read(self, len, buffer)
#    1130 try:
#    1131     if buffer is not None:
# -> 1132         return self._sslobj.read(len, buffer)
#    1133     else:
#    1134         return self._sslobj.read(len)
#
# KeyboardInterrupt:
