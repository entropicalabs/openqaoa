# %%
import networkx as nx
from openqaoa.problems import Knapsack

knapsack_prob = Knapsack(values=[2, 2, 1, 2, 2],weights=[2, 4, 1, 3, 2],weight_capacity=5,penalty=4)
print(knapsack_prob.problem_instance)
knapsack_qubo = knapsack_prob.qubo
knapsack_hamiltonian = knapsack_qubo.hamiltonian
# Out:
# {'problem_type': 'knapsack', 'values': [2, 2, 1, 2, 2], 'weights': [2, 4, 1, 3, 2], 'weight_capacity': 5, 'penalty': 4, 'n_items': 5}

# %%
{'problem_type': 'knapsack', 'values': [2, 2, 1, 2, 2], 'weights': [2, 4, 1, 3, 2], 'weight_capacity': 5, 'penalty': 4, 'n_items': 5}

# %%
from qiskit_ibm_provider import IBMProvider
IBMProvider.save_account('825a8b2e6fb861f63088f866e59357e49447b4b9b24ff6136e56dcc28f2fb0cedda6c2976b9e2aef48129a80864265494be7f8a7aae5b9ebd6654a7d80d9b5cb')

# %%
from tqdm import tqdm
from openqaoa.backends import create_device
from openqaoa import QAOA
from openqaoa.utilities import ground_state_hamiltonian
import matplotlib.pyplot as plt
import json


itr = 0
yahice = range(1,94)
ps = [3, 4, 5, 6]
param_types = ["standard", "standard_w_bias", "annealing"]
init_types = ["rand", "ramp"]
mixer_hams = ["x", "xy"]
optimizers = ["Nelder-Mead", "Powell", "COBYLA"]
for p in tqdm(ps):
    for param_type in tqdm(param_types):
        for init_type in tqdm(init_types):
            for mixer_hamiltonian in tqdm(mixer_hams):
                for optimizer in tqdm(optimizers):
                    print("params = prob3_%s-%s-%s-%s-%s" % (str(p), str(param_type), str(init_type), str(mixer_hamiltonian), str(optimizer)))
                    itr = itr+1
                    print('itr ',itr)
                    if itr in yahice:
                        continue
                    
                    q1 = QAOA()
                    #qiskit_device = create_device(location='local', name='qiskit.shot_simulator')
                    qiskit_device = create_device(location='ibmq', name='ibmq_qasm_simulator')
                    q1.set_device(qiskit_device)
                    q1.set_circuit_properties(p=p, param_type=param_type, init_type=init_type, mixer_hamiltonian=mixer_hamiltonian)
                    q1.set_backend_properties(n_shots=5000, seed_simulator=1)
                    q1.set_classical_optimizer(method=optimizer, maxiter=200, tol=0.01,
                    optimization_progress=True, cost_progress=True, parameter_log=True)
                    q1.compile(knapsack_qubo)
                    q1.optimize()
                    correct_solution1 = ground_state_hamiltonian(q1.cost_hamil)
                    print(correct_solution1)
                    opt_results1 = q1.result

                    with open('prob3_%s-%s-%s-%s-%s.json'% (str(p), str(param_type), str(init_type), str(mixer_hamiltonian), str(optimizer)), 'w') as archivo:
                        json.dump(opt_results1.asdict(), archivo)

                    
                    fig, ax = plt.subplots(figsize=(7,4))
                    opt_results1.plot_cost(figsize=(7,4),color='blue',label='qaoa',ax=ax)
                    plt.savefig("prob3_%s-%s-%s-%s-%s.png" % (str(p), str(param_type), str(init_type), str(mixer_hamiltonian), str(optimizer)))
# Out:
#   0%|                                                                                            | 0/4 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
#
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#
#
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<?, ?it/s]
# params = prob3_3-standard-rand-x-Nelder-Mead
# itr  1
# params = prob3_3-standard-rand-x-Powell
# itr  2
# params = prob3_3-standard-rand-x-COBYLA
# itr  3
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 202.21it/s]
# params = prob3_3-standard-rand-xy-Nelder-Mead
# itr  4
# params = prob3_3-standard-rand-xy-Powell
# itr  5
# params = prob3_3-standard-rand-xy-COBYLA
# itr  6
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#
#
# 100%|██████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 4140.48it/s]
# params = prob3_3-standard-ramp-x-Nelder-Mead
# itr  7
# params = prob3_3-standard-ramp-x-Powell
# itr  8
# params = prob3_3-standard-ramp-x-COBYLA
# itr  9
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 103.78it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 60.21it/s]
# params = prob3_3-standard-ramp-xy-Nelder-Mead
# itr  10
# params = prob3_3-standard-ramp-xy-Powell
# itr  11
# params = prob3_3-standard-ramp-xy-COBYLA
# itr  12
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#
#
# 100%|██████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 5974.79it/s]
# params = prob3_3-standard_w_bias-rand-x-Nelder-Mead
# itr  13
# params = prob3_3-standard_w_bias-rand-x-Powell
# itr  14
# params = prob3_3-standard_w_bias-rand-x-COBYLA
# itr  15
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 112.78it/s]
# params = prob3_3-standard_w_bias-rand-xy-Nelder-Mead
# itr  16
# params = prob3_3-standard_w_bias-rand-xy-Powell
# itr  17
# params = prob3_3-standard_w_bias-rand-xy-COBYLA
# itr  18
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#
#
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<?, ?it/s]
# params = prob3_3-standard_w_bias-ramp-x-Nelder-Mead
# itr  19
# params = prob3_3-standard_w_bias-ramp-x-Powell
# itr  20
# params = prob3_3-standard_w_bias-ramp-x-COBYLA
# itr  21
# 100%|██████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 5997.57it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 260.55it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 53.51it/s]
# params = prob3_3-standard_w_bias-ramp-xy-Nelder-Mead
# itr  22
# params = prob3_3-standard_w_bias-ramp-xy-Powell
# itr  23
# params = prob3_3-standard_w_bias-ramp-xy-COBYLA
# itr  24
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#
#
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<?, ?it/s]
# params = prob3_3-annealing-rand-x-Nelder-Mead
# itr  25
# params = prob3_3-annealing-rand-x-Powell
# itr  26
# params = prob3_3-annealing-rand-x-COBYLA
# itr  27
# 100%|██████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 3000.93it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 250.09it/s]
# params = prob3_3-annealing-rand-xy-Nelder-Mead
# itr  28
# params = prob3_3-annealing-rand-xy-Powell
# itr  29
# params = prob3_3-annealing-rand-xy-COBYLA
# itr  30
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#
#
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<?, ?it/s]
# params = prob3_3-annealing-ramp-x-Nelder-Mead
# itr  31
# params = prob3_3-annealing-ramp-x-Powell
# itr  32
# params = prob3_3-annealing-ramp-x-COBYLA
# itr  33
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 175.28it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 56.89it/s]
#
# 100%|████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 26.49it/s]
#  25%|█████████████████████                                                               | 1/4 [00:00<00:00,  8.21it/s]
# params = prob3_3-annealing-ramp-xy-Nelder-Mead
# itr  34
# params = prob3_3-annealing-ramp-xy-Powell
# itr  35
# params = prob3_3-annealing-ramp-xy-COBYLA
# itr  36
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
#
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#
#
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<?, ?it/s]
# params = prob3_4-standard-rand-x-Nelder-Mead
# itr  37
# params = prob3_4-standard-rand-x-Powell
# itr  38
# params = prob3_4-standard-rand-x-COBYLA
# itr  39
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 395.97it/s]
# params = prob3_4-standard-rand-xy-Nelder-Mead
# itr  40
# params = prob3_4-standard-rand-xy-Powell
# itr  41
# params = prob3_4-standard-rand-xy-COBYLA
# itr  42
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#
#
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<?, ?it/s]
# params = prob3_4-standard-ramp-x-Nelder-Mead
# itr  43
# params = prob3_4-standard-ramp-x-Powell
# itr  44
# params = prob3_4-standard-ramp-x-COBYLA
# itr  45
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 181.82it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 69.45it/s]
# params = prob3_4-standard-ramp-xy-Nelder-Mead
# itr  46
# params = prob3_4-standard-ramp-xy-Powell
# itr  47
# params = prob3_4-standard-ramp-xy-COBYLA
# itr  48
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#
#
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<?, ?it/s]
# params = prob3_4-standard_w_bias-rand-x-Nelder-Mead
# itr  49
# params = prob3_4-standard_w_bias-rand-x-Powell
# itr  50
# params = prob3_4-standard_w_bias-rand-x-COBYLA
# itr  51
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<?, ?it/s]
# params = prob3_4-standard_w_bias-rand-xy-Nelder-Mead
# itr  52
# params = prob3_4-standard_w_bias-rand-xy-Powell
# itr  53
# params = prob3_4-standard_w_bias-rand-xy-COBYLA
# itr  54
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#
#
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<?, ?it/s]
# params = prob3_4-standard_w_bias-ramp-x-Nelder-Mead
# itr  55
# params = prob3_4-standard_w_bias-ramp-x-Powell
# itr  56
# params = prob3_4-standard_w_bias-ramp-x-COBYLA
# itr  57
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 181.81it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 75.78it/s]
# params = prob3_4-standard_w_bias-ramp-xy-Nelder-Mead
# itr  58
# params = prob3_4-standard_w_bias-ramp-xy-Powell
# itr  59
# params = prob3_4-standard_w_bias-ramp-xy-COBYLA
# itr  60
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#
#
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<?, ?it/s]
# params = prob3_4-annealing-rand-x-Nelder-Mead
# itr  61
# params = prob3_4-annealing-rand-x-Powell
# itr  62
# params = prob3_4-annealing-rand-x-COBYLA
# itr  63
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 333.40it/s]
# params = prob3_4-annealing-rand-xy-Nelder-Mead
# itr  64
# params = prob3_4-annealing-rand-xy-Powell
# itr  65
# params = prob3_4-annealing-rand-xy-COBYLA
# itr  66
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#
#
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
# params = prob3_4-annealing-ramp-x-Nelder-Mead
# itr  67
# params = prob3_4-annealing-ramp-x-Powell
# itr  68
# (-5.0, ['00010101'])
#  67%|███████████████████████████████████████████████████████▎                           | 2/3 [09:07<04:33, 273.74s/it]
# params = prob3_4-annealing-ramp-x-COBYLA
# itr  69
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [10:28<00:00, 209.43s/it]
#
#
#
#  50%|█████████████████████████████████████████▌                                         | 1/2 [10:28<10:28, 628.30s/it]
# (-5.0, ['00010101'])
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
# params = prob3_4-annealing-ramp-xy-Nelder-Mead
# itr  70
# (-5.0, ['00010101'])
#  33%|██████████████████████████▋                                                     | 1/3 [38:49<1:17:39, 2329.55s/it]
# params = prob3_4-annealing-ramp-xy-Powell
# itr  71
# (-5.0, ['00010101'])
#  67%|██████████████████████████████████████████████████████▋                           | 2/3 [44:56<19:34, 1174.81s/it]
# params = prob3_4-annealing-ramp-xy-COBYLA
# itr  72
# (-5.0, ['00010101'])
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [49:03<00:00, 981.15s/it]
#
#
#
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [59:31<00:00, 1785.89s/it]
#
#
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [59:31<00:00, 1785.90s/it]
#
# 100%|██████████████████████████████████████████████████████████████████████████████████| 3/3 [59:31<00:00, 1190.62s/it]
#  50%|████████████████████████████████████████                                        | 2/4 [59:31<1:10:02, 2101.15s/it]
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
#
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#
#
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
# params = prob3_5-standard-rand-x-Nelder-Mead
# itr  73
# (-5.0, ['00010101'])
#  33%|███████████████████████████▎                                                      | 1/3 [28:42<57:25, 1722.67s/it]
# params = prob3_5-standard-rand-x-Powell
# itr  74
# (-5.0, ['00010101'])
#  67%|██████████████████████████████████████████████████████▋                           | 2/3 [57:16<28:37, 1717.51s/it]
# params = prob3_5-standard-rand-x-COBYLA
# itr  75
# (-5.0, ['00010101'])
# 100%|████████████████████████████████████████████████████████████████████████████████| 3/3 [1:00:13<00:00, 1204.67s/it]
#
#
#
#  50%|███████████████████████████████████████                                       | 1/2 [1:00:13<1:00:13, 3614.00s/it]
#
#
#
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
# params = prob3_5-standard-rand-xy-Nelder-Mead
# itr  76
# (-5.0, ['00010101'])
#  33%|██████████████████████████▋                                                     | 1/3 [45:42<1:31:24, 2742.49s/it]
# params = prob3_5-standard-rand-xy-Powell
# itr  77
# (-5.0, ['00010101'])
#  67%|████████████████████████████████████████████████████                          | 2/3 [2:02:23<1:03:55, 3835.90s/it]
# params = prob3_5-standard-rand-xy-COBYLA
# itr  78
# 100%|████████████████████████████████████████████████████████████████████████████████| 3/3 [2:07:23<00:00, 2547.87s/it]
#
#
#
# 100%|████████████████████████████████████████████████████████████████████████████████| 2/2 [3:07:37<00:00, 5628.80s/it]
#
#
#  50%|██████████████████████████████████████▌                                      | 1/2 [3:07:37<3:07:37, 11257.60s/it]
# (-5.0, ['00010101'])
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#
#
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
# params = prob3_5-standard-ramp-x-Nelder-Mead
# itr  79
# (-5.0, ['00010101'])
#  33%|███████████████████████████▎                                                      | 1/3 [28:34<57:09, 1714.75s/it]
# params = prob3_5-standard-ramp-x-Powell
# itr  80
# (-5.0, ['00010101'])
#  67%|██████████████████████████████████████████████████████▋                           | 2/3 [50:15<24:31, 1471.21s/it]
# params = prob3_5-standard-ramp-x-COBYLA
# itr  81
# (-5.0, ['00010101'])
# 100%|██████████████████████████████████████████████████████████████████████████████████| 3/3 [53:40<00:00, 1073.34s/it]
#
#
#
#  50%|█████████████████████████████████████████                                         | 1/2 [53:40<53:40, 3220.02s/it]
#
#
#
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
# params = prob3_5-standard-ramp-xy-Nelder-Mead
# itr  82
# (-5.0, ['00010101'])
#  33%|██████████████████████████▋                                                     | 1/3 [44:51<1:29:43, 2691.94s/it]
# params = prob3_5-standard-ramp-xy-Powell
# itr  83
# (-5.0, ['00010101'])
#  67%|█████████████████████████████████████████████████████▎                          | 2/3 [1:03:05<29:11, 1751.92s/it]
# params = prob3_5-standard-ramp-xy-COBYLA
# itr  84
# (-5.0, ['00010101'])
# 100%|████████████████████████████████████████████████████████████████████████████████| 3/3 [1:08:25<00:00, 1368.56s/it]
#
#
#
# 100%|████████████████████████████████████████████████████████████████████████████████| 2/2 [2:02:05<00:00, 3662.87s/it]
#
#
# 100%|████████████████████████████████████████████████████████████████████████████████| 2/2 [5:09:43<00:00, 9291.68s/it]
#
#  33%|█████████████████████████▎                                                  | 1/3 [5:09:43<10:19:26, 18583.36s/it]
#
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#
#
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
# params = prob3_5-standard_w_bias-rand-x-Nelder-Mead
# itr  85
# (-5.0, ['00010101'])
#  33%|██████████████████████████▋                                                     | 1/3 [33:39<1:07:18, 2019.29s/it]
# params = prob3_5-standard_w_bias-rand-x-Powell
# itr  86
# (-5.0, ['00010101'])
#  67%|█████████████████████████████████████████████████████▎                          | 2/3 [1:46:04<56:27, 3387.48s/it]
# params = prob3_5-standard_w_bias-rand-x-COBYLA
# itr  87
# (-5.0, ['00010101'])
# 100%|████████████████████████████████████████████████████████████████████████████████| 3/3 [1:52:02<00:00, 2240.97s/it]
#
#
#
#  50%|███████████████████████████████████████                                       | 1/2 [1:52:02<1:52:02, 6722.93s/it]
#
#
#
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
# params = prob3_5-standard_w_bias-rand-xy-Nelder-Mead
# itr  88
# (-5.0, ['00010101'])
# C:\Users\Adriano\AppData\Local\Temp\ipykernel_5500\571897820.py:45: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, ax = plt.subplots(figsize=(7,4))
#
#
#
#
#  33%|██████████████████████████▋                                                     | 1/3 [56:31<1:53:03, 3391.54s/it]
# params = prob3_5-standard_w_bias-rand-xy-Powell
# itr  89
# (-5.0, ['00010101'])
#  67%|█████████████████████████████████████████████████████▎                          | 2/3 [1:42:55<50:34, 3034.09s/it]
# params = prob3_5-standard_w_bias-rand-xy-COBYLA
# itr  90
# (-5.0, ['00010101'])
# 100%|████████████████████████████████████████████████████████████████████████████████| 3/3 [1:50:32<00:00, 2210.89s/it]
#
#
#
# 100%|████████████████████████████████████████████████████████████████████████████████| 2/2 [3:42:35<00:00, 6677.80s/it]
#
#
#  50%|██████████████████████████████████████▌                                      | 1/2 [3:42:35<3:42:35, 13355.60s/it]
#
#
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#
#
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
# params = prob3_5-standard_w_bias-ramp-x-Nelder-Mead
# itr  91
# (-5.0, ['00010101'])
#  33%|██████████████████████████▋                                                     | 1/3 [36:44<1:13:29, 2204.71s/it]
# params = prob3_5-standard_w_bias-ramp-x-Powell
# itr  92
# (-5.0, ['00010101'])
#  67%|█████████████████████████████████████████████████████▎                          | 2/3 [1:03:25<30:49, 1849.25s/it]
# params = prob3_5-standard_w_bias-ramp-x-COBYLA
# itr  93
# (-5.0, ['00010101'])
# 100%|████████████████████████████████████████████████████████████████████████████████| 3/3 [1:09:26<00:00, 1388.89s/it]
#
#
#
#  50%|███████████████████████████████████████                                       | 1/2 [1:09:26<1:09:26, 4166.67s/it]
#
#
#
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
# params = prob3_5-standard_w_bias-ramp-xy-Nelder-Mead
# itr  94
#   0%|                                                                                            | 0/3 [29:17<?, ?it/s]
#  50%|███████████████████████████████████████                                       | 1/2 [1:38:44<1:38:44, 5924.09s/it]
#  50%|██████████████████████████████████████▌                                      | 1/2 [5:21:19<5:21:19, 19279.70s/it]
#  33%|█████████████████████████                                                  | 1/3 [10:31:03<21:02:06, 37863.06s/it]
#  50%|█████████████████████████████████████▌                                     | 2/4 [11:30:35<11:30:35, 20717.53s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 36
#      33 q1.set_classical_optimizer(method=optimizer, maxiter=200, tol=0.01,
#      34 optimization_progress=True, cost_progress=True, parameter_log=True)
#      35 q1.compile(knapsack_qubo)
# ---> 36 q1.optimize()
#      37 correct_solution1 = ground_state_hamiltonian(q1.cost_hamil)
#      38 print(correct_solution1)
#
# File ~\anaconda3\envs\quantum\lib\site-packages\openqaoa\algorithms\qaoa\qaoa_workflow.py:371, in QAOA.optimize(self, verbose)
#     368 # timestamp for the start of the optimization
#     369 self.header["execution_time_start"] = generate_timestamp()
# --> 371 self.optimizer.optimize()
#     372 # TODO: result and qaoa_result will differ
#     373 self.result = self.optimizer.qaoa_result
#
# File ~\anaconda3\envs\quantum\lib\site-packages\openqaoa\optimizers\training_vqa.py:499, in ScipyOptimizer.optimize(self)
#     487             result = minimize(
#     488                 self.optimize_this,
#     489                 x0=self.initial_params,
#    (...)
#     496                 bounds=self.bounds,
#     497             )
#     498     else:
# --> 499         result = minimize(
#     500             self.optimize_this,
#     501             x0=self.initial_params,
#     502             method=self.method,
#     503             tol=self.tol,
#     504             constraints=self.constraints,
#     505             options=self.options,
#     506             bounds=self.bounds,
#     507         )
#     508 except ConnectionError as e:
#     509     print(e, "\n")
#
# File ~\anaconda3\envs\quantum\lib\site-packages\scipy\optimize\_minimize.py:684, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     681     bounds = standardize_bounds(bounds, x0, meth)
#     683 if meth == 'nelder-mead':
# --> 684     res = _minimize_neldermead(fun, x0, args, callback, bounds=bounds,
#     685                                **options)
#     686 elif meth == 'powell':
#     687     res = _minimize_powell(fun, x0, args, callback, bounds, **options)
#
# File ~\anaconda3\envs\quantum\lib\site-packages\scipy\optimize\_optimize.py:895, in _minimize_neldermead(func, x0, args, callback, maxiter, maxfev, disp, return_all, initial_simplex, xatol, fatol, adaptive, bounds, **unknown_options)
#     893 if bounds is not None:
#     894     xc = np.clip(xc, lower_bound, upper_bound)
# --> 895 fxc = func(xc)
#     897 if fxc <= fxr:
#     898     sim[-1] = xc
#
# File ~\anaconda3\envs\quantum\lib\site-packages\scipy\optimize\_optimize.py:569, in _wrap_scalar_function_maxfun_validation.<locals>.function_wrapper(x, *wrapper_args)
#     567 ncalls[0] += 1
#     568 # A copy of x is sent to the user function (gh13740)
# --> 569 fx = function(np.copy(x), *(wrapper_args + args))
#     570 # Ideally, we'd like to a have a true scalar returned from f(x). For
#     571 # backwards-compatibility, also allow np.array([1.3]),
#     572 # np.array([[1.3]]) etc.
#     573 if not np.isscalar(fx):
#
# File ~\anaconda3\envs\quantum\lib\site-packages\openqaoa\optimizers\training_vqa.py:232, in OptimizeVQA.optimize_this(self, x, n_shots)
#     229     save_parameter("param_log", deepcopy(x))
#     231 n_shots_dict = {"n_shots": n_shots} if n_shots else {}
# --> 232 callback_cost = self.vqa.expectation(self.variational_params, **n_shots_dict)
#     234 log_dict.update({"cost": callback_cost})
#     236 current_eval = self.log.func_evals.best[0]
#
# File ~\anaconda3\envs\quantum\lib\site-packages\openqaoa\utilities.py:252, in round_value.<locals>.wrapper(*args, **kwargs)
#     251 def wrapper(*args, **kwargs):
# --> 252     values = function(*args, **kwargs)
#     253     if isinstance(values, dict):
#     254         return {k: round(v, PRECISION) for k, v in values.items()}
#
# File ~\anaconda3\envs\quantum\lib\site-packages\openqaoa\backends\basebackend.py:282, in QAOABaseBackend.expectation(self, params, n_shots)
#     264 @round_value
#     265 def expectation(self, params: QAOAVariationalBaseParams, n_shots=None) -> float:
#     266     """
#     267     Compute the expectation value w.r.t the Cost Hamiltonian
#     268
#    (...)
#     280         Expectation value of cost operator wrt to quantum state produced by QAOA circuit
#     281     """
# --> 282     counts = self.get_counts(params, n_shots)
#     283     cost = cost_function(
#     284         counts, self.qaoa_descriptor.cost_hamiltonian, self.cvar_alpha
#     285     )
#     286     return cost
#
# File ~\anaconda3\envs\quantum\lib\site-packages\openqaoa_qiskit\backends\qaoa_qiskit_qpu.py:253, in QAOAQiskitQPUBackend.get_counts(self, params, n_shots)
#     251 try:
#     252     self.job_id = job.job_id()
# --> 253     counts = job.result().get_counts()
#     254     api_contact = True
#     255     job_state = True
#
# File ~\anaconda3\envs\quantum\lib\site-packages\qiskit_ibm_provider\job\ibm_circuit_job.py:248, in IBMCircuitJob.result(self, timeout, refresh)
#     246 # pylint: disable=arguments-differ
#     247 if self._result is None or refresh:
# --> 248     self.wait_for_final_state(timeout=timeout)
#     249     if self._status is JobStatus.CANCELLED:
#     250         raise IBMJobInvalidStateError(
#     251             "Unable to retrieve result for job {}. "
#     252             "Job was cancelled.".format(self.job_id())
#     253         )
#
# File ~\anaconda3\envs\quantum\lib\site-packages\qiskit_ibm_provider\job\ibm_circuit_job.py:669, in IBMCircuitJob.wait_for_final_state(self, timeout, wait)
#     665         if timeout is not None and elapsed_time >= timeout:
#     666             raise IBMJobTimeoutError(
#     667                 f"Timed out waiting for job to complete after {timeout} secs."
#     668             )
# --> 669         time.sleep(wait)
#     670         status = self.status()
#     671 except futures.TimeoutError:
#
# KeyboardInterrupt:
