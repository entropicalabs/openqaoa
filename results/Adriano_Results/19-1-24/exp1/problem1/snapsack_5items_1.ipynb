# %%
import networkx as nx
from openqaoa.problems import Knapsack

knapsack_prob = Knapsack(values=[4, 1, 4, 2, 2],weights=[4, 2, 4, 1, 3],weight_capacity=7,penalty=8)
print(knapsack_prob.problem_instance)
knapsack_qubo = knapsack_prob.qubo
knapsack_hamiltonian = knapsack_qubo.hamiltonian
# Out:
# {'problem_type': 'knapsack', 'values': [4, 1, 4, 2, 2], 'weights': [4, 2, 4, 1, 3], 'weight_capacity': 7, 'penalty': 8, 'n_items': 5}

# %%
{'problem_type': 'knapsack', 'values': [4, 1, 4, 2, 2], 'weights': [4, 2, 4, 1, 3], 'weight_capacity': 7, 'penalty': 8, 'n_items': 5}

# %%
from qiskit_ibm_provider import IBMProvider
IBMProvider.save_account('825a8b2e6fb861f63088f866e59357e49447b4b9b24ff6136e56dcc28f2fb0cedda6c2976b9e2aef48129a80864265494be7f8a7aae5b9ebd6654a7d80d9b5cb')

# %%
from tqdm import tqdm
from openqaoa.backends import create_device
from openqaoa import QAOA
from openqaoa.utilities import ground_state_hamiltonian
import matplotlib.pyplot as plt
import json

itr = 0
yahice = range(1,88)
ps = [3, 4, 5, 6]
param_types = ["standard", "standard_w_bias", "annealing"]
init_types = ["rand", "ramp"]
mixer_hams = ["x", "xy"]
optimizers = ["Nelder-Mead", "Powell", "COBYLA"]
for p in tqdm(ps):
    for param_type in tqdm(param_types):
        for init_type in tqdm(init_types):
            for mixer_hamiltonian in tqdm(mixer_hams):
                for optimizer in tqdm(optimizers):
                    print("params = prob1_%s-%s-%s-%s-%s" % (str(p), str(param_type), str(init_type), str(mixer_hamiltonian), str(optimizer)))
                    itr = itr+1
                    print('itr ',itr)
                    if itr in yahice:
                        continue
                    
                    q1 = QAOA()
                    #qiskit_device = create_device(location='local', name='qiskit.shot_simulator')
                    qiskit_device = create_device(location='ibmq', name='ibmq_qasm_simulator')
                    q1.set_device(qiskit_device)
                    q1.set_circuit_properties(p=p, param_type=param_type, init_type=init_type, mixer_hamiltonian=mixer_hamiltonian)
                    q1.set_backend_properties(n_shots=5000, seed_simulator=1)
                    q1.set_classical_optimizer(method=optimizer, maxiter=200, tol=0.01,
                    optimization_progress=True, cost_progress=True, parameter_log=True)
                    q1.compile(knapsack_qubo)
                    q1.optimize()
                    correct_solution1 = ground_state_hamiltonian(q1.cost_hamil)
                    print(correct_solution1)
                    opt_results1 = q1.result

                    with open('prob1_%s-%s-%s-%s-%s.json'% (str(p), str(param_type), str(init_type), str(mixer_hamiltonian), str(optimizer)), 'w') as archivo:
                        json.dump(opt_results1.asdict(), archivo)

                    
                    fig, ax = plt.subplots(figsize=(7,4))
                    opt_results1.plot_cost(figsize=(7,4),color='blue',label='qaoa',ax=ax)
                    plt.savefig("prob1_%s-%s-%s-%s-%s.png" % (str(p), str(param_type), str(init_type), str(mixer_hamiltonian), str(optimizer)))
# Out:
#   0%|                                                                                            | 0/4 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
#
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#
#
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<?, ?it/s]
# params = prob1_3-standard-rand-x-Nelder-Mead
# itr  1
# params = prob1_3-standard-rand-x-Powell
# itr  2
# params = prob1_3-standard-rand-x-COBYLA
# itr  3
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 134.71it/s]
# params = prob1_3-standard-rand-xy-Nelder-Mead
# itr  4
# params = prob1_3-standard-rand-xy-Powell
# itr  5
# params = prob1_3-standard-rand-xy-COBYLA
# itr  6
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#
#
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<?, ?it/s]
# params = prob1_3-standard-ramp-x-Nelder-Mead
# itr  7
# params = prob1_3-standard-ramp-x-Powell
# itr  8
# params = prob1_3-standard-ramp-x-COBYLA
# itr  9
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 232.41it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 59.58it/s]
# params = prob1_3-standard-ramp-xy-Nelder-Mead
# itr  10
# params = prob1_3-standard-ramp-xy-Powell
# itr  11
# params = prob1_3-standard-ramp-xy-COBYLA
# itr  12
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#
#
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<?, ?it/s]
# params = prob1_3-standard_w_bias-rand-x-Nelder-Mead
# itr  13
# params = prob1_3-standard_w_bias-rand-x-Powell
# itr  14
# params = prob1_3-standard_w_bias-rand-x-COBYLA
# itr  15
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 179.19it/s]
# params = prob1_3-standard_w_bias-rand-xy-Nelder-Mead
# itr  16
# params = prob1_3-standard_w_bias-rand-xy-Powell
# itr  17
# params = prob1_3-standard_w_bias-rand-xy-COBYLA
# itr  18
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#
#
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<?, ?it/s]
# params = prob1_3-standard_w_bias-ramp-x-Nelder-Mead
# itr  19
# params = prob1_3-standard_w_bias-ramp-x-Powell
# itr  20
# params = prob1_3-standard_w_bias-ramp-x-COBYLA
# itr  21
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 101.92it/s]
# params = prob1_3-standard_w_bias-ramp-xy-Nelder-Mead
# itr  22
# params = prob1_3-standard_w_bias-ramp-xy-Powell
# itr  23
# params = prob1_3-standard_w_bias-ramp-xy-COBYLA
# itr  24
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#
#
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<?, ?it/s]
# params = prob1_3-annealing-rand-x-Nelder-Mead
# itr  25
# params = prob1_3-annealing-rand-x-Powell
# itr  26
# params = prob1_3-annealing-rand-x-COBYLA
# itr  27
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<?, ?it/s]
# params = prob1_3-annealing-rand-xy-Nelder-Mead
# itr  28
# params = prob1_3-annealing-rand-xy-Powell
# itr  29
# params = prob1_3-annealing-rand-xy-COBYLA
# itr  30
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#
#
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<?, ?it/s]
# params = prob1_3-annealing-ramp-x-Nelder-Mead
# itr  31
# params = prob1_3-annealing-ramp-x-Powell
# itr  32
# params = prob1_3-annealing-ramp-x-COBYLA
# itr  33
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 471.69it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 112.02it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 30.03it/s]
#  25%|█████████████████████                                                               | 1/4 [00:00<00:00,  9.55it/s]
# params = prob1_3-annealing-ramp-xy-Nelder-Mead
# itr  34
# params = prob1_3-annealing-ramp-xy-Powell
# itr  35
# params = prob1_3-annealing-ramp-xy-COBYLA
# itr  36
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
#
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#
#
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<?, ?it/s]
# params = prob1_4-standard-rand-x-Nelder-Mead
# itr  37
# params = prob1_4-standard-rand-x-Powell
# itr  38
# params = prob1_4-standard-rand-x-COBYLA
# itr  39
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<?, ?it/s]
# params = prob1_4-standard-rand-xy-Nelder-Mead
# itr  40
# params = prob1_4-standard-rand-xy-Powell
# itr  41
# params = prob1_4-standard-rand-xy-COBYLA
# itr  42
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#
#
# 100%|██████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 3039.35it/s]
# params = prob1_4-standard-ramp-x-Nelder-Mead
# itr  43
# params = prob1_4-standard-ramp-x-Powell
# itr  44
# params = prob1_4-standard-ramp-x-COBYLA
# itr  45
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 269.50it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 93.99it/s]
# params = prob1_4-standard-ramp-xy-Nelder-Mead
# itr  46
# params = prob1_4-standard-ramp-xy-Powell
# itr  47
# params = prob1_4-standard-ramp-xy-COBYLA
# itr  48
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#
#
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<?, ?it/s]
# params = prob1_4-standard_w_bias-rand-x-Nelder-Mead
# itr  49
# params = prob1_4-standard_w_bias-rand-x-Powell
# itr  50
# params = prob1_4-standard_w_bias-rand-x-COBYLA
# itr  51
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 146.51it/s]
# params = prob1_4-standard_w_bias-rand-xy-Nelder-Mead
# itr  52
# params = prob1_4-standard_w_bias-rand-xy-Powell
# itr  53
# params = prob1_4-standard_w_bias-rand-xy-COBYLA
# itr  54
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#
#
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<?, ?it/s]
# params = prob1_4-standard_w_bias-ramp-x-Nelder-Mead
# itr  55
# params = prob1_4-standard_w_bias-ramp-x-Powell
# itr  56
# params = prob1_4-standard_w_bias-ramp-x-COBYLA
# itr  57
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 154.62it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 70.90it/s]
# params = prob1_4-standard_w_bias-ramp-xy-Nelder-Mead
# itr  58
# params = prob1_4-standard_w_bias-ramp-xy-Powell
# itr  59
# params = prob1_4-standard_w_bias-ramp-xy-COBYLA
# itr  60
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#
#
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<?, ?it/s]
# params = prob1_4-annealing-rand-x-Nelder-Mead
# itr  61
# params = prob1_4-annealing-rand-x-Powell
# itr  62
# params = prob1_4-annealing-rand-x-COBYLA
# itr  63
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
# params = prob1_4-annealing-rand-xy-Nelder-Mead
# itr  64
# (-7.0, ['00011010', '00001110'])
#  33%|██████████████████████████▋                                                     | 1/3 [39:30<1:19:01, 2370.67s/it]
# params = prob1_4-annealing-rand-xy-Powell
# itr  65
# (-7.0, ['00011010', '00001110'])
#  67%|██████████████████████████████████████████████████████▋                           | 2/3 [58:45<27:35, 1655.69s/it]
# params = prob1_4-annealing-rand-xy-COBYLA
# itr  66
# 100%|████████████████████████████████████████████████████████████████████████████████| 3/3 [1:01:08<00:00, 1222.82s/it]
#
#
#
# 100%|████████████████████████████████████████████████████████████████████████████████| 2/2 [1:01:08<00:00, 1834.23s/it]
#
#
#  50%|███████████████████████████████████████                                       | 1/2 [1:01:08<1:01:08, 3668.45s/it]
# (-7.0, ['00011010', '00001110'])
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#
#
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
# params = prob1_4-annealing-ramp-x-Nelder-Mead
# itr  67
# (-7.0, ['00011010', '00001110'])
#  33%|███████████████████████████▎                                                      | 1/3 [26:30<53:01, 1590.92s/it]
# params = prob1_4-annealing-ramp-x-Powell
# itr  68
# (-7.0, ['00011010', '00001110'])
#  67%|██████████████████████████████████████████████████████▋                           | 2/3 [37:48<17:33, 1053.69s/it]
# params = prob1_4-annealing-ramp-x-COBYLA
# itr  69
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [39:29<00:00, 789.78s/it]
#
#
#
#  50%|█████████████████████████████████████████                                         | 1/2 [39:29<39:29, 2369.36s/it]
# (-7.0, ['00011010', '00001110'])
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
# params = prob1_4-annealing-ramp-xy-Nelder-Mead
# itr  70
# (-7.0, ['00011010', '00001110'])
#  33%|██████████████████████████▋                                                     | 1/3 [38:36<1:17:12, 2316.43s/it]
# params = prob1_4-annealing-ramp-xy-Powell
# itr  71
# (-7.0, ['00011010', '00001110'])
#  67%|██████████████████████████████████████████████████████▋                           | 2/3 [50:05<22:39, 1359.40s/it]
# params = prob1_4-annealing-ramp-xy-COBYLA
# itr  72
# 100%|██████████████████████████████████████████████████████████████████████████████████| 3/3 [52:26<00:00, 1048.76s/it]
#
#
#
# 100%|████████████████████████████████████████████████████████████████████████████████| 2/2 [1:31:55<00:00, 2757.82s/it]
#
#
# 100%|████████████████████████████████████████████████████████████████████████████████| 2/2 [2:33:04<00:00, 4592.05s/it]
#
# 100%|████████████████████████████████████████████████████████████████████████████████| 3/3 [2:33:04<00:00, 3061.39s/it]
#  50%|███████████████████████████████████████                                       | 2/4 [2:33:04<3:00:04, 5402.50s/it]
# (-7.0, ['00011010', '00001110'])
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
#
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#
#
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
# params = prob1_5-standard-rand-x-Nelder-Mead
# itr  73
# (-7.0, ['00011010', '00001110'])
#  33%|███████████████████████████▎                                                      | 1/3 [28:07<56:14, 1687.37s/it]
# params = prob1_5-standard-rand-x-Powell
# itr  74
# (-7.0, ['00011010', '00001110'])
#  67%|██████████████████████████████████████████████████████▋                           | 2/3 [40:54<19:06, 1146.20s/it]
# params = prob1_5-standard-rand-x-COBYLA
# itr  75
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [44:00<00:00, 880.03s/it]
#
#
#
#  50%|█████████████████████████████████████████                                         | 1/2 [44:00<44:00, 2640.10s/it]
# (-7.0, ['00011010', '00001110'])
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
# params = prob1_5-standard-rand-xy-Nelder-Mead
# itr  76
# (-7.0, ['00011010', '00001110'])
#  33%|██████████████████████████▋                                                     | 1/3 [47:33<1:35:06, 2853.31s/it]
# params = prob1_5-standard-rand-xy-Powell
# itr  77
# (-7.0, ['00011010', '00001110'])
#  67%|█████████████████████████████████████████████████████▎                          | 2/3 [1:52:41<57:53, 3473.64s/it]
# params = prob1_5-standard-rand-xy-COBYLA
# itr  78
# 100%|████████████████████████████████████████████████████████████████████████████████| 3/3 [1:57:10<00:00, 2343.34s/it]
#
#
#
# 100%|████████████████████████████████████████████████████████████████████████████████| 2/2 [2:41:10<00:00, 4835.07s/it]
#
#
#  50%|███████████████████████████████████████                                       | 1/2 [2:41:10<2:41:10, 9670.15s/it]
# (-7.0, ['00011010', '00001110'])
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#
#
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
# params = prob1_5-standard-ramp-x-Nelder-Mead
# itr  79
# (-7.0, ['00011010', '00001110'])
#  33%|██████████████████████████▋                                                     | 1/3 [34:45<1:09:31, 2085.92s/it]
# params = prob1_5-standard-ramp-x-Powell
# itr  80
# (-7.0, ['00011010', '00001110'])
#  67%|████████████████████████████████████████████████████                          | 2/3 [2:15:02<1:13:17, 4397.83s/it]
# params = prob1_5-standard-ramp-x-COBYLA
# itr  81
# (-7.0, ['00011010', '00001110'])
# 100%|████████████████████████████████████████████████████████████████████████████████| 3/3 [2:19:12<00:00, 2784.31s/it]
#
#
#
#  50%|███████████████████████████████████████                                       | 1/2 [2:19:12<2:19:12, 8352.92s/it]
#
#
#
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
# params = prob1_5-standard-ramp-xy-Nelder-Mead
# itr  82
# (-7.0, ['00011010', '00001110'])
#  33%|██████████████████████████▋                                                     | 1/3 [57:45<1:55:31, 3465.77s/it]
# params = prob1_5-standard-ramp-xy-Powell
# itr  83
# (-7.0, ['00011010', '00001110'])
#  67%|█████████████████████████████████████████████████████▎                          | 2/3 [1:29:08<42:14, 2534.68s/it]
# params = prob1_5-standard-ramp-xy-COBYLA
# itr  84
# (-7.0, ['00011010', '00001110'])
# C:\Users\Adriano\AppData\Local\Temp\ipykernel_16176\3564487267.py:44: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, ax = plt.subplots(figsize=(7,4))
#
#
#
#
# 100%|████████████████████████████████████████████████████████████████████████████████| 3/3 [1:35:44<00:00, 1914.72s/it]
#
#
#
# 100%|████████████████████████████████████████████████████████████████████████████████| 2/2 [3:54:57<00:00, 7048.55s/it]
#
#
# 100%|███████████████████████████████████████████████████████████████████████████████| 2/2 [6:36:07<00:00, 11883.63s/it]
#
#  33%|█████████████████████████▎                                                  | 1/3 [6:36:07<13:12:14, 23767.27s/it]
#
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#
#
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
# params = prob1_5-standard_w_bias-rand-x-Nelder-Mead
# itr  85
# (-7.0, ['00011010', '00001110'])
#  33%|██████████████████████████▋                                                     | 1/3 [45:53<1:31:46, 2753.24s/it]
# params = prob1_5-standard_w_bias-rand-x-Powell
# itr  86
# (-7.0, ['00011010', '00001110'])
#  67%|█████████████████████████████████████████████████████▎                          | 2/3 [1:47:23<55:04, 3304.47s/it]
# params = prob1_5-standard_w_bias-rand-x-COBYLA
# itr  87
# (-7.0, ['00011010', '00001110'])
# 100%|████████████████████████████████████████████████████████████████████████████████| 3/3 [1:52:48<00:00, 2256.29s/it]
#
#
#
#  50%|███████████████████████████████████████                                       | 1/2 [1:52:48<1:52:48, 6768.87s/it]
#
#
#
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
# params = prob1_5-standard_w_bias-rand-xy-Nelder-Mead
# itr  88
#   0%|                                                                                            | 0/3 [34:32<?, ?it/s]
#  50%|███████████████████████████████████████                                       | 1/2 [2:27:21<2:27:21, 8841.71s/it]
#   0%|                                                                                          | 0/2 [2:27:21<?, ?it/s]
#  33%|█████████████████████████▎                                                  | 1/3 [9:03:29<18:06:58, 32609.01s/it]
#  50%|█████████████████████████████████████▌                                     | 2/4 [11:36:33<11:36:33, 20896.65s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 35
#      32 q1.set_classical_optimizer(method=optimizer, maxiter=200, tol=0.01,
#      33 optimization_progress=True, cost_progress=True, parameter_log=True)
#      34 q1.compile(knapsack_qubo)
# ---> 35 q1.optimize()
#      36 correct_solution1 = ground_state_hamiltonian(q1.cost_hamil)
#      37 print(correct_solution1)
#
# File ~\anaconda3\envs\quantum\lib\site-packages\openqaoa\algorithms\qaoa\qaoa_workflow.py:371, in QAOA.optimize(self, verbose)
#     368 # timestamp for the start of the optimization
#     369 self.header["execution_time_start"] = generate_timestamp()
# --> 371 self.optimizer.optimize()
#     372 # TODO: result and qaoa_result will differ
#     373 self.result = self.optimizer.qaoa_result
#
# File ~\anaconda3\envs\quantum\lib\site-packages\openqaoa\optimizers\training_vqa.py:499, in ScipyOptimizer.optimize(self)
#     487             result = minimize(
#     488                 self.optimize_this,
#     489                 x0=self.initial_params,
#    (...)
#     496                 bounds=self.bounds,
#     497             )
#     498     else:
# --> 499         result = minimize(
#     500             self.optimize_this,
#     501             x0=self.initial_params,
#     502             method=self.method,
#     503             tol=self.tol,
#     504             constraints=self.constraints,
#     505             options=self.options,
#     506             bounds=self.bounds,
#     507         )
#     508 except ConnectionError as e:
#     509     print(e, "\n")
#
# File ~\anaconda3\envs\quantum\lib\site-packages\scipy\optimize\_minimize.py:684, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     681     bounds = standardize_bounds(bounds, x0, meth)
#     683 if meth == 'nelder-mead':
# --> 684     res = _minimize_neldermead(fun, x0, args, callback, bounds=bounds,
#     685                                **options)
#     686 elif meth == 'powell':
#     687     res = _minimize_powell(fun, x0, args, callback, bounds, **options)
#
# File ~\anaconda3\envs\quantum\lib\site-packages\scipy\optimize\_optimize.py:870, in _minimize_neldermead(func, x0, args, callback, maxiter, maxfev, disp, return_all, initial_simplex, xatol, fatol, adaptive, bounds, **unknown_options)
#     868 if bounds is not None:
#     869     xr = np.clip(xr, lower_bound, upper_bound)
# --> 870 fxr = func(xr)
#     871 doshrink = 0
#     873 if fxr < fsim[0]:
#
# File ~\anaconda3\envs\quantum\lib\site-packages\scipy\optimize\_optimize.py:569, in _wrap_scalar_function_maxfun_validation.<locals>.function_wrapper(x, *wrapper_args)
#     567 ncalls[0] += 1
#     568 # A copy of x is sent to the user function (gh13740)
# --> 569 fx = function(np.copy(x), *(wrapper_args + args))
#     570 # Ideally, we'd like to a have a true scalar returned from f(x). For
#     571 # backwards-compatibility, also allow np.array([1.3]),
#     572 # np.array([[1.3]]) etc.
#     573 if not np.isscalar(fx):
#
# File ~\anaconda3\envs\quantum\lib\site-packages\openqaoa\optimizers\training_vqa.py:232, in OptimizeVQA.optimize_this(self, x, n_shots)
#     229     save_parameter("param_log", deepcopy(x))
#     231 n_shots_dict = {"n_shots": n_shots} if n_shots else {}
# --> 232 callback_cost = self.vqa.expectation(self.variational_params, **n_shots_dict)
#     234 log_dict.update({"cost": callback_cost})
#     236 current_eval = self.log.func_evals.best[0]
#
# File ~\anaconda3\envs\quantum\lib\site-packages\openqaoa\utilities.py:252, in round_value.<locals>.wrapper(*args, **kwargs)
#     251 def wrapper(*args, **kwargs):
# --> 252     values = function(*args, **kwargs)
#     253     if isinstance(values, dict):
#     254         return {k: round(v, PRECISION) for k, v in values.items()}
#
# File ~\anaconda3\envs\quantum\lib\site-packages\openqaoa\backends\basebackend.py:282, in QAOABaseBackend.expectation(self, params, n_shots)
#     264 @round_value
#     265 def expectation(self, params: QAOAVariationalBaseParams, n_shots=None) -> float:
#     266     """
#     267     Compute the expectation value w.r.t the Cost Hamiltonian
#     268
#    (...)
#     280         Expectation value of cost operator wrt to quantum state produced by QAOA circuit
#     281     """
# --> 282     counts = self.get_counts(params, n_shots)
#     283     cost = cost_function(
#     284         counts, self.qaoa_descriptor.cost_hamiltonian, self.cvar_alpha
#     285     )
#     286     return cost
#
# File ~\anaconda3\envs\quantum\lib\site-packages\openqaoa_qiskit\backends\qaoa_qiskit_qpu.py:253, in QAOAQiskitQPUBackend.get_counts(self, params, n_shots)
#     251 try:
#     252     self.job_id = job.job_id()
# --> 253     counts = job.result().get_counts()
#     254     api_contact = True
#     255     job_state = True
#
# File ~\anaconda3\envs\quantum\lib\site-packages\qiskit_ibm_provider\job\ibm_circuit_job.py:257, in IBMCircuitJob.result(self, timeout, refresh)
#     255         error_message = self.error_message()
#     256         raise IBMJobFailureError(f"Job failed: " f"{error_message}")
# --> 257     self._retrieve_result(refresh=refresh)
#     258 return self._result
#
# File ~\anaconda3\envs\quantum\lib\site-packages\qiskit_ibm_provider\job\ibm_circuit_job.py:731, in IBMCircuitJob._retrieve_result(self, refresh)
#     728         api_result = self._api_client.job_result(self.job_id())
#     729     else:
#     730         api_result = self._download_external_result(
# --> 731             self._runtime_client.job_results(self.job_id())
#     732         )
#     734     self._set_result(api_result)
#     735 except ApiError as err:
#
# File ~\anaconda3\envs\quantum\lib\site-packages\qiskit_ibm_provider\api\clients\runtime.py:245, in RuntimeClient.job_results(self, job_id)
#     236 def job_results(self, job_id: str) -> str:
#     237     """Get the results of a program job.
#     238
#     239     Args:
#    (...)
#     243         Job result.
#     244     """
# --> 245     return self._api.program_job(job_id).results()
#
# File ~\anaconda3\envs\quantum\lib\site-packages\qiskit_ibm_provider\api\rest\program_job.py:94, in ProgramJob.results(self)
#      88 def results(self) -> str:
#      89     """Return program job results.
#      90
#      91     Returns:
#      92         Job results.
#      93     """
# ---> 94     response = self.session.get(self.get_url("results"))
#      95     return response.text
#
# File ~\anaconda3\envs\quantum\lib\site-packages\requests\sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File ~\anaconda3\envs\quantum\lib\site-packages\qiskit_ibm_provider\api\session.py:263, in RetrySession.request(self, method, url, bare, **kwargs)
#     261 try:
#     262     self._log_request_info(final_url, method, kwargs)
# --> 263     response = super().request(method, final_url, headers=headers, **kwargs)
#     264     response.raise_for_status()
#     265 except RequestException as ex:
#     266     # Wrap the requests exceptions into a IBM Q custom one, for
#     267     # compatibility.
#
# File ~\anaconda3\envs\quantum\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\anaconda3\envs\quantum\lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\anaconda3\envs\quantum\lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~\anaconda3\envs\quantum\lib\site-packages\urllib3\connectionpool.py:715, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     712     self._prepare_proxy(conn)
#     714 # Make the request on the httplib connection object.
# --> 715 httplib_response = self._make_request(
#     716     conn,
#     717     method,
#     718     url,
#     719     timeout=timeout_obj,
#     720     body=body,
#     721     headers=headers,
#     722     chunked=chunked,
#     723 )
#     725 # If we're going to release the connection in ``finally:``, then
#     726 # the response doesn't need to know about the connection. Otherwise
#     727 # it will also try to release it and we'll have a double-release
#     728 # mess.
#     729 response_conn = conn if not release_conn else None
#
# File ~\anaconda3\envs\quantum\lib\site-packages\urllib3\connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     462             httplib_response = conn.getresponse()
#     463         except BaseException as e:
#     464             # Remove the TypeError from the exception chain in
#     465             # Python 3 (including for exceptions like SystemExit).
#     466             # Otherwise it looks like a bug in the code.
# --> 467             six.raise_from(e, None)
#     468 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     469     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~\anaconda3\envs\quantum\lib\site-packages\urllib3\connectionpool.py:462, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     459 except TypeError:
#     460     # Python 3
#     461     try:
# --> 462         httplib_response = conn.getresponse()
#     463     except BaseException as e:
#     464         # Remove the TypeError from the exception chain in
#     465         # Python 3 (including for exceptions like SystemExit).
#     466         # Otherwise it looks like a bug in the code.
#     467         six.raise_from(e, None)
#
# File ~\anaconda3\envs\quantum\lib\http\client.py:1348, in HTTPConnection.getresponse(self)
#    1346 try:
#    1347     try:
# -> 1348         response.begin()
#    1349     except ConnectionError:
#    1350         self.close()
#
# File ~\anaconda3\envs\quantum\lib\http\client.py:316, in HTTPResponse.begin(self)
#     314 # read until we get a non-100 response
#     315 while True:
# --> 316     version, status, reason = self._read_status()
#     317     if status != CONTINUE:
#     318         break
#
# File ~\anaconda3\envs\quantum\lib\http\client.py:277, in HTTPResponse._read_status(self)
#     276 def _read_status(self):
# --> 277     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     278     if len(line) > _MAXLINE:
#     279         raise LineTooLong("status line")
#
# File ~\anaconda3\envs\quantum\lib\socket.py:669, in SocketIO.readinto(self, b)
#     667 while True:
#     668     try:
# --> 669         return self._sock.recv_into(b)
#     670     except timeout:
#     671         self._timeout_occurred = True
#
# File ~\anaconda3\envs\quantum\lib\ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File ~\anaconda3\envs\quantum\lib\ssl.py:1132, in SSLSocket.read(self, len, buffer)
#    1130 try:
#    1131     if buffer is not None:
# -> 1132         return self._sslobj.read(len, buffer)
#    1133     else:
#    1134         return self._sslobj.read(len)
#
# KeyboardInterrupt:
